# %% [markdown]
# ### Preview Data

# %%
from fastai.vision.all import *
#hide
from fastbook import *

# %%
path = Path("../data/usq/train/images")

# %%
#fnames = get_image_files(path/"images")
fnames = get_image_files(path)

# %%
img = PILImage.create(fnames[0])
mask = PILMask.create(str(fnames[0]).replace('images','masks'))
#mask = PILMask.create(str(fnames[0]).replace('mipimages','mipmasks'))
ax = img.show()
ax = mask.show(ctx=ax)

# %% [markdown]
# ### Load Data

# %%
from fastai.vision.all import *
#hide
from fastbook import *

# %%
#path = Path("../data/usq/train/images")
#path = Path("../data/usq/imageprojections/all/images")
path = Path("../data/usq/imageprojections/p9/images")

# %%
def get_msk(fname):
    "Grab a mask from a `filename` and adjust the pixels based on `pix2class`"
    fn = str(fname).replace('images','masks')
    msk = np.array(PILMask.create(fn))
    msk = (msk > 100)
    msk = (msk * 1).astype(np.uint8)
    return PILMask.create(msk)

# %%
codes = ['Background', 'CV']

# %%
def get_y(o):
    return get_msk(o)

# %%
img_size = (320, 566)

# %%
dblock = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=get_image_files,
                   splitter=RandomSplitter(),
                   get_y=get_y,
                   #item_tfms=Resize((320, 247)))#, method=ResizeMethod.Pad, pad_mode = PadMode.Zeros),
                   item_tfms=Resize(img_size),#, method=ResizeMethod.Pad, pad_mode = PadMode.Zeros),
                   batch_tfms=[Normalize.from_stats(*imagenet_stats)])
                   #batch_tfms = [RandomResizedCrop((247, 320)), 
                   #          *aug_transforms(mult=1.0, do_flip=True, 
                   #                          max_rotate=30.0, max_zoom=1.5,
                   #                           max_lighting=.8, max_warp=0.3, 
                   #                          p_lighting=.9)])

# %%
dsets = dblock.datasets(path)

dls = dblock.dataloaders(path, bs=2)
#dls = dblock.dataloaders(path, bs=8)
dls.vocab = codes

# %%
dls.show_batch()

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Dense U-Net

# %%
import sys
sys.path.append('/home/msadmin/notebooks/msc8001/src')
from dense_unet import *
from fastai import *
# Out:
# 2021-12-02 13:03:48,153 util_log.py[147] INFO Start the program at:msdsvm, 10.0.0.4, with:Load module
# Adjust wk folder for notebook failed

# %%
encoder = nn.Sequential(*list(models.densenet121().children())[0])
#encoder = efficient_unet(1)
unet = DynamicUnet(encoder, n_classes=2, img_size=(img_size), blur=False, blur_final=False,
                    self_attention=False, y_range=None, norm_type=NormType,
                    last_cross=True,
                    bottle=False)
#print(unet(torch.rand(1,3,224,224)).shape)
# Out:
#     sn        layer     c    w    h               size
# 2    2         ReLU    64  160  283  (1, 64, 160, 283)
# 8    8  _DenseBlock  1024   20   35  (1, 1024, 20, 35)
# 11  11  BatchNorm2d  1024   10   17  (1, 1024, 10, 17)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ### Weighted Cross Entropy Loss Function

# %%
class CrossEntropyLossFlat(BaseLoss):
    "Same as `nn.CrossEntropyLoss`, but flattens input and target."
    y_int = True
    def __init__(self, *args, axis=-1, **kwargs): super().__init__(nn.CrossEntropyLoss, *args, axis=axis, **kwargs)
    def decodes(self, x):    return x.argmax(dim=self.axis)
    def activation(self, x): return F.softmax(x, dim=self.axis)

# %%
weights = torch.tensor([[0.5] + [2.5]]).cuda()
weights
# Out:
# tensor([[0.5000, 2.5000]], device='cuda:0')

# %%
loss_func = CrossEntropyLossFlat(weight=weights, axis=1)

# %%
learn = unet_learner(dls, resnet34, Dice(), metrics=[foreground_acc, Dice()])

# %%
# use customer weighted loss function
#learn = Learner(dls, unet, loss_func=loss_func, metrics=[foreground_acc, Dice()])
learn = Learner(dls, unet, metrics=[foreground_acc, Dice()])
#learn.summary()

# %%
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))

# %%
learn.fit_one_cycle(12)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.071397</td>
#       <td>0.096534</td>
#       <td>0.339912</td>
#       <td>0.475112</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.173185</td>
#       <td>0.258582</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.193642</td>
#       <td>0.158300</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.183778</td>
#       <td>0.139744</td>
#       <td>0.160755</td>
#       <td>0.257700</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.172401</td>
#       <td>0.103699</td>
#       <td>0.593631</td>
#       <td>0.627084</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.159381</td>
#       <td>0.088404</td>
#       <td>0.420099</td>
#       <td>0.537088</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.147558</td>
#       <td>0.085883</td>
#       <td>0.550248</td>
#       <td>0.633654</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.137422</td>
#       <td>0.076598</td>
#       <td>0.639207</td>
#       <td>0.687590</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.128564</td>
#       <td>0.074836</td>
#       <td>0.744756</td>
#       <td>0.723844</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.121283</td>
#       <td>0.074610</td>
#       <td>0.768593</td>
#       <td>0.728217</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.115152</td>
#       <td>0.073433</td>
#       <td>0.695462</td>
#       <td>0.711540</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.110047</td>
#       <td>0.073415</td>
#       <td>0.686880</td>
#       <td>0.708741</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(12, lrs.steep, 
                    cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.1, patience=3, min_lr=lrs.minimum),
                                         EarlyStoppingCallback(monitor='dice', min_delta=0.01, patience=5),
                                         SaveModelCallback(monitor='dice', min_delta=0.01)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.319438</td>
#       <td>0.260110</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.286134</td>
#       <td>0.212135</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.245258</td>
#       <td>0.172302</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.210156</td>
#       <td>0.163745</td>
#       <td>0.000572</td>
#       <td>0.001143</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.184309</td>
#       <td>0.205874</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.164742</td>
#       <td>0.119081</td>
#       <td>0.057685</td>
#       <td>0.107949</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.150466</td>
#       <td>0.110836</td>
#       <td>0.125095</td>
#       <td>0.216752</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.138816</td>
#       <td>0.156279</td>
#       <td>0.020690</td>
#       <td>0.040451</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.129123</td>
#       <td>0.092795</td>
#       <td>0.384439</td>
#       <td>0.514680</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.121506</td>
#       <td>0.101676</td>
#       <td>0.308924</td>
#       <td>0.446312</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.114802</td>
#       <td>0.100263</td>
#       <td>0.334668</td>
#       <td>0.469471</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.109402</td>
#       <td>0.093816</td>
#       <td>0.408181</td>
#       <td>0.532297</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.0.
# Better model found at epoch 5 with dice value: 0.10794896957801767.
# Better model found at epoch 6 with dice value: 0.21675202378985628.
# Better model found at epoch 8 with dice value: 0.5146796017360225.
# Better model found at epoch 11 with dice value: 0.5322971712775878.

# %%
learn.unfreeze()
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))

# %%
print(f"Minimum/10: {lrs.minimum:.2e}, steepest point: {lrs.steep:.2e}")
# Out:
# Minimum/10: 1.91e-07, steepest point: 1.32e-06

# %%
learn.fit_one_cycle(100, #lrs.steep, 
                    cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.1, patience=5, min_lr=lrs.minimum),
                                         EarlyStoppingCallback(monitor='foreground_acc', min_delta=0.01, patience=15),
                                         SaveModelCallback(monitor='foreground_acc', min_delta=0.01)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.058960</td>
#       <td>0.070982</td>
#       <td>0.848303</td>
#       <td>0.751087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.058865</td>
#       <td>0.068706</td>
#       <td>0.815408</td>
#       <td>0.752353</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.058534</td>
#       <td>0.067879</td>
#       <td>0.795385</td>
#       <td>0.750484</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.058284</td>
#       <td>0.068144</td>
#       <td>0.802822</td>
#       <td>0.751149</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.058035</td>
#       <td>0.067597</td>
#       <td>0.783658</td>
#       <td>0.748816</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.057802</td>
#       <td>0.068794</td>
#       <td>0.825610</td>
#       <td>0.754630</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.057424</td>
#       <td>0.067123</td>
#       <td>0.734077</td>
#       <td>0.739684</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.057072</td>
#       <td>0.069236</td>
#       <td>0.809211</td>
#       <td>0.753195</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.056818</td>
#       <td>0.067801</td>
#       <td>0.806445</td>
#       <td>0.754808</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.056854</td>
#       <td>0.124376</td>
#       <td>0.977403</td>
#       <td>0.677797</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.059487</td>
#       <td>0.104599</td>
#       <td>0.970061</td>
#       <td>0.694281</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.061518</td>
#       <td>0.091931</td>
#       <td>0.270118</td>
#       <td>0.407919</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.063725</td>
#       <td>0.090090</td>
#       <td>0.936690</td>
#       <td>0.728810</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.064703</td>
#       <td>0.070213</td>
#       <td>0.838101</td>
#       <td>0.754086</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.064421</td>
#       <td>0.070723</td>
#       <td>0.850496</td>
#       <td>0.752203</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.063828</td>
#       <td>0.077032</td>
#       <td>0.915236</td>
#       <td>0.746655</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.063178</td>
#       <td>0.064327</td>
#       <td>0.796720</td>
#       <td>0.760708</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.062215</td>
#       <td>0.065726</td>
#       <td>0.797006</td>
#       <td>0.760601</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.061098</td>
#       <td>0.066348</td>
#       <td>0.839340</td>
#       <td>0.768083</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.062098</td>
#       <td>0.074379</td>
#       <td>0.446606</td>
#       <td>0.583567</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.062560</td>
#       <td>0.075591</td>
#       <td>0.923246</td>
#       <td>0.747953</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.062268</td>
#       <td>0.070273</td>
#       <td>0.872426</td>
#       <td>0.763009</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.061281</td>
#       <td>0.064732</td>
#       <td>0.801678</td>
#       <td>0.766384</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.060123</td>
#       <td>0.064501</td>
#       <td>0.811404</td>
#       <td>0.759381</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.058908</td>
#       <td>0.065951</td>
#       <td>0.858410</td>
#       <td>0.771829</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with foreground_acc value: 0.8483028411865234.
# Epoch 5: reducing lr to 3.981071640737355e-05
# Better model found at epoch 9 with foreground_acc value: 0.9774027466773987.
# Epoch 10: reducing lr to 4.15291254655705e-05
# Epoch 15: reducing lr to 7.106309809055481e-05
# Epoch 20: reducing lr to 9.331561601509122e-05
# No improvement since epoch 9: early stopping

# %%
learn.fit_one_cycle(100, #lrs.steep, 
                    cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.1, patience=5, min_lr=lrs.minimum),
                                         EarlyStoppingCallback(monitor='dice', min_delta=0.01, patience=15),
                                         SaveModelCallback(monitor='dice', min_delta=0.01)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.075447</td>
#       <td>0.073209</td>
#       <td>0.705854</td>
#       <td>0.715923</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.075335</td>
#       <td>0.075898</td>
#       <td>0.845919</td>
#       <td>0.734407</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.074283</td>
#       <td>0.073829</td>
#       <td>0.817029</td>
#       <td>0.734087</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.072846</td>
#       <td>0.072881</td>
#       <td>0.683543</td>
#       <td>0.709697</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.071728</td>
#       <td>0.075091</td>
#       <td>0.875286</td>
#       <td>0.742208</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.070724</td>
#       <td>0.068453</td>
#       <td>0.761537</td>
#       <td>0.741631</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.069360</td>
#       <td>0.070643</td>
#       <td>0.788234</td>
#       <td>0.741934</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.068229</td>
#       <td>0.070303</td>
#       <td>0.836671</td>
#       <td>0.752218</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.066601</td>
#       <td>0.066930</td>
#       <td>0.807018</td>
#       <td>0.754670</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.065406</td>
#       <td>0.077825</td>
#       <td>0.903509</td>
#       <td>0.750663</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.064615</td>
#       <td>0.070515</td>
#       <td>0.569699</td>
#       <td>0.665516</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.063990</td>
#       <td>0.081936</td>
#       <td>0.467868</td>
#       <td>0.589182</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.066618</td>
#       <td>0.088126</td>
#       <td>0.948894</td>
#       <td>0.729539</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.066398</td>
#       <td>0.069043</td>
#       <td>0.772025</td>
#       <td>0.742878</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.065812</td>
#       <td>0.077239</td>
#       <td>0.907132</td>
#       <td>0.750108</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.065069</td>
#       <td>0.079175</td>
#       <td>0.913997</td>
#       <td>0.748059</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.064764</td>
#       <td>0.099717</td>
#       <td>0.963101</td>
#       <td>0.708966</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.064801</td>
#       <td>0.064115</td>
#       <td>0.759630</td>
#       <td>0.749377</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.065148</td>
#       <td>0.086897</td>
#       <td>0.406465</td>
#       <td>0.547943</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.065804</td>
#       <td>0.069458</td>
#       <td>0.847254</td>
#       <td>0.758677</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.067012</td>
#       <td>0.089250</td>
#       <td>0.950610</td>
#       <td>0.720298</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.067085</td>
#       <td>0.085585</td>
#       <td>0.948989</td>
#       <td>0.725384</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.067103</td>
#       <td>0.080918</td>
#       <td>0.938120</td>
#       <td>0.734446</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.7159228277162613.
# Better model found at epoch 1 with dice value: 0.7344066884648814.
# Epoch 5: reducing lr to 3.981071640737355e-05
# Better model found at epoch 7 with dice value: 0.7522180789507522.
# Epoch 10: reducing lr to 4.15291254655705e-05
# Epoch 15: reducing lr to 7.106309809055481e-05
# Epoch 20: reducing lr to 9.331561601509122e-05
# No improvement since epoch 7: early stopping

# %%
learn.fit_one_cycle(100, #lrs.steep, 
                    cbs=[ReduceLROnPlateau(monitor='valid_loss', min_delta=0.1, patience=5, min_lr=lrs.minimum),
                                         EarlyStoppingCallback(monitor='dice', min_delta=0.01, patience=15),
                                         SaveModelCallback(monitor='dice', min_delta=0.01)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.117333</td>
#       <td>0.126952</td>
#       <td>0.356817</td>
#       <td>0.513965</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.131734</td>
#       <td>0.136025</td>
#       <td>0.313339</td>
#       <td>0.468030</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.130627</td>
#       <td>0.088501</td>
#       <td>0.696189</td>
#       <td>0.761485</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.126900</td>
#       <td>0.104292</td>
#       <td>0.935319</td>
#       <td>0.804757</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.128342</td>
#       <td>0.095358</td>
#       <td>0.886205</td>
#       <td>0.819457</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.126013</td>
#       <td>0.104248</td>
#       <td>0.467391</td>
#       <td>0.619255</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.126012</td>
#       <td>0.090167</td>
#       <td>0.673376</td>
#       <td>0.758292</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.124349</td>
#       <td>0.094423</td>
#       <td>0.880837</td>
#       <td>0.815708</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.123166</td>
#       <td>0.099890</td>
#       <td>0.544149</td>
#       <td>0.675777</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.121793</td>
#       <td>0.084176</td>
#       <td>0.741412</td>
#       <td>0.783077</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.119824</td>
#       <td>0.083413</td>
#       <td>0.748926</td>
#       <td>0.801120</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.118576</td>
#       <td>0.103751</td>
#       <td>0.517713</td>
#       <td>0.661977</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.116989</td>
#       <td>0.089655</td>
#       <td>0.712292</td>
#       <td>0.756449</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.114797</td>
#       <td>0.077070</td>
#       <td>0.758588</td>
#       <td>0.808958</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.112976</td>
#       <td>0.098943</td>
#       <td>0.601181</td>
#       <td>0.702580</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.110888</td>
#       <td>0.073977</td>
#       <td>0.774289</td>
#       <td>0.819079</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.109382</td>
#       <td>0.148225</td>
#       <td>0.306763</td>
#       <td>0.454925</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.108113</td>
#       <td>0.075526</td>
#       <td>0.773081</td>
#       <td>0.813413</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.107425</td>
#       <td>0.148674</td>
#       <td>0.273484</td>
#       <td>0.414902</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.107235</td>
#       <td>0.079919</td>
#       <td>0.808239</td>
#       <td>0.812437</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.5139654005992075.
# Better model found at epoch 2 with dice value: 0.7614853955672978.
# Better model found at epoch 3 with dice value: 0.8047569564715391.
# Better model found at epoch 4 with dice value: 0.8194565082516442.
# Epoch 5: reducing lr to 1.5994669073816726e-05
# Epoch 10: reducing lr to 4.15291254655705e-05
# Epoch 15: reducing lr to 7.106309809055481e-05
# No improvement since epoch 4: early stopping

# %%
learn.recorder.plot_loss()

# %% [markdown]
# ## Results

# %%
learn.show_results()

# %%
interp = SegmentationInterpretation.from_learner(learn)
interp.plot_top_losses(k=1)

# %% [markdown]
# ### Save model

# %%
#export model as pickle
#learn.export('dense_unet_mip_images_model.pkl')
learn.save('dense_unet_mip_images_model_p9')
# Out:
# Path('models/dense_unet_mip_images_model_p9.pth')

# %%
learn.export('dense_unet_mip_images_model_p999')
