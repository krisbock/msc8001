# %%
from fastai.vision.all import *
#hide
from fastbook import *

# %%
path = Path("../data/usq/train/images")

# %%
#fnames = get_image_files(path/"images")
fnames = get_image_files(path)

# %%
img = PILImage.create(fnames[0])
mask = PILMask.create(str(fnames[0]).replace('images','masks'))
#mask = PILMask.create(str(fnames[0]).replace('mipimages','mipmasks'))
ax = img.show()
ax = mask.show(ctx=ax)

# %% [markdown]
# ### Load Data

# %%
from fastai.vision.all import *
#hide
from fastbook import *

# %%
path = Path("../data/usq/train/images")

# %%
def get_msk(fname):
    "Grab a mask from a `filename` and adjust the pixels based on `pix2class`"
    fn = str(fname).replace('images','masks')
    msk = np.array(PILMask.create(fn))
    msk = (msk > 100)
    msk = (msk * 1).astype(np.uint8)
    return PILMask.create(msk)

# %%
codes = ['Background', 'CV']

# %%
def get_y(o):
    return get_msk(o)

# %%
dblock = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=get_image_files,
                   splitter=RandomSplitter(),
                   get_y=get_y,
                   item_tfms=Resize(224),
                   batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
dsets = dblock.datasets(path)

# %%
#dls = dblock.dataloaders(path, bs=4)
dls = dblock.dataloaders(path, bs=8)
dls.vocab = codes

# %%
dls.show_batch()

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Vanilla U-Net

# %%
#original unet
learn = unet_learner(dls, resnet34, CrossEntropyLossFlat(axis=1), metrics=[foreground_acc, Dice()])
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))

# %%
print(f"Minimum/10: {lrs.minimum:.2e}, steepest point: {lrs.steep:.2e}")
# Out:
# Minimum/10: 2.29e-03, steepest point: 7.59e-05

# %%
learn.fit_one_cycle(3, 3e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.144109</td>
#       <td>0.119949</td>
#       <td>0.627330</td>
#       <td>0.646734</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.102959</td>
#       <td>0.103324</td>
#       <td>0.791117</td>
#       <td>0.723621</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.087011</td>
#       <td>0.087016</td>
#       <td>0.699119</td>
#       <td>0.726841</td>
#       <td>01:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))

# %%
learn.fit_one_cycle(12, lr_max=slice(1e-5,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.062790</td>
#       <td>0.070737</td>
#       <td>0.883848</td>
#       <td>0.808323</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.065573</td>
#       <td>0.072059</td>
#       <td>0.785289</td>
#       <td>0.784763</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.067480</td>
#       <td>0.071862</td>
#       <td>0.886278</td>
#       <td>0.806742</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.064553</td>
#       <td>0.070320</td>
#       <td>0.899092</td>
#       <td>0.813625</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.060139</td>
#       <td>0.063115</td>
#       <td>0.881648</td>
#       <td>0.825965</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.058496</td>
#       <td>0.061672</td>
#       <td>0.820959</td>
#       <td>0.815044</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.055885</td>
#       <td>0.061916</td>
#       <td>0.819319</td>
#       <td>0.816855</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.052454</td>
#       <td>0.060915</td>
#       <td>0.849289</td>
#       <td>0.827086</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.052623</td>
#       <td>0.059749</td>
#       <td>0.868532</td>
#       <td>0.832270</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.049750</td>
#       <td>0.060641</td>
#       <td>0.828203</td>
#       <td>0.822945</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.047294</td>
#       <td>0.060755</td>
#       <td>0.844892</td>
#       <td>0.828101</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.047318</td>
#       <td>0.060292</td>
#       <td>0.870838</td>
#       <td>0.834509</td>
#       <td>01:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.export('base_unet_model.pkl')

# %% [markdown]
# ### Dense U-Net

# %%
import sys
sys.path.append('/home/msadmin/notebooks/msc8001/src')
from dense_unet import *
from fastai import *
# Out:
# 2021-10-11 13:53:25,365 util_log.py[147] INFO Start the program at:msdsvm, 10.0.0.4, with:Load module
# Adjust wk folder for notebook failed

# %%
encoder = nn.Sequential(*list(models.densenet121().children())[0])
unet = DynamicUnet(encoder, n_classes=2, img_size=(224, 224), blur=False, blur_final=False,
#                     self_attention=False, y_range=None, norm_type=NormType,
#                     last_cross=True,
#                     bottle=False)
#unet = DynamicUnet(encoder, n_classes=2, img_size=(320, 320), blur=False, blur_final=False,
                    self_attention=False, y_range=None, norm_type=NormType,
                    last_cross=True,
                    bottle=False)
#print(unet(torch.rand(1,3,224,224)).shape)
# Out:
#     sn        layer     c    w    h               size
# 2    2         ReLU    64  112  112  (1, 64, 112, 112)
# 4    4  _DenseBlock   256   56   56   (1, 256, 56, 56)
# 6    6  _DenseBlock   512   28   28   (1, 512, 28, 28)
# 8    8  _DenseBlock  1024   14   14  (1, 1024, 14, 14)
# 11  11  BatchNorm2d  1024    7    7    (1, 1024, 7, 7)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
learn = Learner(dls, unet, CrossEntropyLossFlat(axis=1), metrics=[foreground_acc])
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.038740</td>
#       <td>0.044601</td>
#       <td>0.928793</td>
#       <td>07:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))

# %%
print(f"Minimum/10: {lrs.minimum:.2e}, steepest point: {lrs.steep:.2e}")
# Out:
# Minimum/10: 7.59e-08, steepest point: 4.79e-06

# %%
learn = Learner(dls, unet, CrossEntropyLossFlat(axis=1), metrics=[foreground_acc])
learn.fit_one_cycle(12, lr_max=slice(lrs.minimum, lrs.steep))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.035723</td>
#       <td>0.044585</td>
#       <td>0.928800</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.038172</td>
#       <td>0.044636</td>
#       <td>0.928451</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.040596</td>
#       <td>0.044770</td>
#       <td>0.927874</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.037489</td>
#       <td>0.044831</td>
#       <td>0.927340</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.036460</td>
#       <td>0.044958</td>
#       <td>0.926644</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.038200</td>
#       <td>0.045078</td>
#       <td>0.926094</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.038247</td>
#       <td>0.045143</td>
#       <td>0.925723</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.035932</td>
#       <td>0.045116</td>
#       <td>0.925863</td>
#       <td>07:53</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.039358</td>
#       <td>0.045155</td>
#       <td>0.925620</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.036066</td>
#       <td>0.045231</td>
#       <td>0.925234</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.039657</td>
#       <td>0.045182</td>
#       <td>0.925514</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.037527</td>
#       <td>0.045186</td>
#       <td>0.925490</td>
#       <td>07:56</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Weighted Cross Entropy Loss Function

# %%
class CrossEntropyLossFlat(BaseLoss):
    "Same as `nn.CrossEntropyLoss`, but flattens input and target."
    y_int = True
    def __init__(self, *args, axis=-1, **kwargs): super().__init__(nn.CrossEntropyLoss, *args, axis=axis, **kwargs)
    def decodes(self, x):    return x.argmax(dim=self.axis)
    def activation(self, x): return F.softmax(x, dim=self.axis)

# %%
weights = torch.tensor([[0.5] + [1.5]]).cuda()
weights
# Out:
# tensor([[0.5000, 1.5000]], device='cuda:0')

# %%
loss_func = CrossEntropyLossFlat(weight=weights, axis=1)

# %%
# use customer weighted loss function
learn = Learner(dls, unet, loss_func=loss_func, metrics=[foreground_acc, Dice()])
learn.summary()
# Out:
# DynamicUnet (Input shape: 8)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      8 x 64 x 112 x 112
# Conv2d                                    9408       True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# BatchNorm2d                               128        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 56 x 56
# Conv2d                                    8192       True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 56 x 56
# Conv2d                                    36864      True
# BatchNorm2d                               192        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 56 x 56
# Conv2d                                    12288      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 56 x 56
# Conv2d                                    36864      True
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    16384      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 56 x 56
# Conv2d                                    36864      True
# BatchNorm2d                               320        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 56 x 56
# Conv2d                                    20480      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 56 x 56
# Conv2d                                    36864      True
# BatchNorm2d                               384        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 56 x 56
# Conv2d                                    24576      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 56 x 56
# Conv2d                                    36864      True
# BatchNorm2d                               448        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 56 x 56
# Conv2d                                    28672      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 56 x 56
# Conv2d                                    36864      True
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 56 x 56
# Conv2d                                    32768      True
# ____________________________________________________________________________
#                      []
# AvgPool2d
# BatchNorm2d                               256        True
# ReLU
# Conv2d                                    16384      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               320        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    20480      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               384        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    24576      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               448        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    28672      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    32768      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               576        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               640        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    40960      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               704        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    45056      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               768        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    49152      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               832        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    53248      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               896        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    57344      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               960        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 28 x 28
# Conv2d                                    61440      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 28 x 28
# Conv2d                                    36864      True
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      8 x 256 x 28 x 28
# Conv2d                                    131072     True
# ____________________________________________________________________________
#                      []
# AvgPool2d
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    32768      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               576        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               640        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    40960      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               704        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    45056      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               768        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    49152      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               832        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    53248      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               896        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    57344      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               960        True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    61440      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    65536      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1088       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    69632      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1152       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    73728      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1216       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    77824      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1280       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    81920      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1344       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    86016      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1408       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    90112      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1472       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    94208      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1536       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    98304      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1600       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    102400     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1664       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    106496     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1728       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    110592     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1792       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    114688     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1856       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    118784     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1920       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    122880     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               1984       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 14 x 14
# Conv2d                                    126976     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 14 x 14
# Conv2d                                    36864      True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      8 x 512 x 14 x 14
# Conv2d                                    524288     True
# ____________________________________________________________________________
#                      []
# AvgPool2d
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    65536      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1088       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    69632      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1152       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    73728      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1216       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    77824      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1280       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    81920      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1344       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    86016      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1408       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    90112      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1472       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    94208      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1536       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    98304      True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1600       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    102400     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1664       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    106496     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1728       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    110592     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1792       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    114688     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1856       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    118784     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1920       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    122880     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               1984       True
# ReLU
# ____________________________________________________________________________
#                      8 x 128 x 7 x 7
# Conv2d                                    126976     True
# BatchNorm2d                               256        True
# ReLU
# ____________________________________________________________________________
#                      8 x 32 x 7 x 7
# Conv2d                                    36864      True
# BatchNorm2d                               2048       True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      8 x 2048 x 7 x 7
# Conv2d                                    18876416   True
# ReLU
# ____________________________________________________________________________
#                      8 x 1024 x 7 x 7
# Conv2d                                    18875392   True
# ReLU
# ____________________________________________________________________________
#                      8 x 2048 x 7 x 7
# Conv2d                                    2099200    True
# ReLU
# PixelShuffle
# BatchNorm2d                               2048       True
# Conv2d                                    21235200   True
# ReLU
# Conv2d                                    21235200   True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      8 x 3072 x 14 x 14
# Conv2d                                    4721664    True
# ReLU
# PixelShuffle
# BatchNorm2d                               1024       True
# Conv2d                                    14746880   True
# ReLU
# Conv2d                                    14746880   True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      8 x 2560 x 28 x 28
# Conv2d                                    3279360    True
# ReLU
# PixelShuffle
# BatchNorm2d                               512        True
# Conv2d                                    7226240    True
# ReLU
# Conv2d                                    7226240    True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      8 x 1792 x 56 x 56
# Conv2d                                    1607424    True
# ReLU
# PixelShuffle
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      8 x 256 x 112 x 112
# Conv2d                                    1179904    True
# ReLU
# Conv2d                                    590080     True
# ReLU
# ReLU
# ____________________________________________________________________________
#                      8 x 1024 x 112 x 11
# Conv2d                                    263168     True
# ReLU
# PixelShuffle
# MergeLayer
# Conv2d                                    603988     True
# ReLU
# Conv2d                                    603988     True
# Sequential
# ReLU
# ____________________________________________________________________________
#                      8 x 2 x 224 x 224
# Conv2d                                    520        True
# ____________________________________________________________________________
#
# Total params: 146,077,360
# Total trainable params: 146,077,360
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f5d326dd560>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='222' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/222 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-87d07278d32d> in <module>
# ----> 1 lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/callback/schedule.py in lr_find(self, start_lr, end_lr, num_it, stop_div, show_plot, suggest_funcs)
#     280     n_epoch = num_it//len(self.dls.train) + 1
#     281     cb=LRFinder(start_lr=start_lr, end_lr=end_lr, num_it=num_it, stop_div=stop_div)
# --> 282     with self.no_logging(): self.fit(n_epoch, cbs=cb)
#     283     if suggest_funcs is not None:
#     284         lrs, losses = tensor(self.recorder.lrs[num_it//10:-5]), tensor(self.recorder.losses[num_it//10:-5])
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     219             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     220             self.n_epoch = n_epoch
# --> 221             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     222
#     223     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_fit(self)
#     210         for epoch in range(self.n_epoch):
#     211             self.epoch=epoch
# --> 212             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     213
#     214     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_epoch(self)
#     204
#     205     def _do_epoch(self):
# --> 206         self._do_epoch_train()
#     207         self._do_epoch_validate()
#     208
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_epoch_train(self)
#     196     def _do_epoch_train(self):
#     197         self.dl = self.dls.train
# --> 198         self._with_events(self.all_batches, 'train', CancelTrainException)
#     199
#     200     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in all_batches(self)
#     167     def all_batches(self):
#     168         self.n_iter = len(self.dl)
# --> 169         for o in enumerate(self.dl): self.one_batch(*o)
#     170
#     171     def _do_one_batch(self):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in one_batch(self, i, b)
#     192         b = self._set_device(b)
#     193         self._split(b)
# --> 194         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     195
#     196     def _do_epoch_train(self):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_one_batch(self)
#     170
#     171     def _do_one_batch(self):
# --> 172         self.pred = self.model(*self.xb)
#     173         self('after_pred')
#     174         if len(self.yb):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/layers.py in forward(self, x)
#     405         for l in self.layers:
#     406             res.orig = x
# --> 407             nres = l(res)
#     408             # We have to remove res.orig to avoid hanging refs and therefore memory leaks
#     409             res.orig, nres.orig = None, None
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/vision/models/unet.py in forward(self, up_in)
#      33     def forward(self, up_in):
#      34         s = self.hook.stored
# ---> 35         up_out = self.shuf(up_in)
#      36         ssh = s.shape[-2:]
#      37         if ssh != up_out.shape[-2:]:
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     418                             _pair(0), self.dilation, self.groups)
#     419         return F.conv2d(input, weight, self.bias, self.stride,
# --> 420                         self.padding, self.dilation, self.groups)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/torch_core.py in __torch_function__(self, func, types, args, kwargs)
#     338         convert=False
#     339         if _torch_handled(args, self._opt, func): convert,types = type(self),(torch.Tensor,)
# --> 340         res = super().__torch_function__(func, types, args=args, kwargs=kwargs)
#     341         if convert: res = convert(res)
#     342         if isinstance(res, TensorBase): res.set_meta(self, as_copy=True)
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/tensor.py in __torch_function__(cls, func, types, args, kwargs)
#     993
#     994         with _C.DisableTorchFunction():
# --> 995             ret = func(*args, **kwargs)
#     996             return _convert(ret, cls)
#     997
#
# RuntimeError: CUDA out of memory. Tried to allocate 172.00 MiB (GPU 0; 15.78 GiB total capacity; 12.48 GiB already allocated; 7.50 MiB free; 12.75 GiB reserved in total by PyTorch)

# %%
learn.fit_one_cycle(3, 2e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.062693</td>
#       <td>0.063633</td>
#       <td>0.990589</td>
#       <td>0.861365</td>
#       <td>08:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.057441</td>
#       <td>0.085919</td>
#       <td>0.957480</td>
#       <td>0.856171</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.053625</td>
#       <td>0.056779</td>
#       <td>0.990281</td>
#       <td>0.869778</td>
#       <td>07:54</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
lrs = learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))

# %%
print(f"Minimum/10: {lrs.minimum:.2e}, steepest point: {lrs.steep:.2e}")
# Out:
# Minimum/10: 5.25e-04, steepest point: 1.32e-06

# %%
learn.fit_one_cycle(12, lr_max=slice(8e-3, 1e-2))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [4/12 31:42<1:03:24]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.071223</td>
#       <td>0.070294</td>
#       <td>0.977222</td>
#       <td>0.851256</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>516.812561</td>
#       <td>0.495445</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.557424</td>
#       <td>0.492355</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.495332</td>
#       <td>0.492489</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>07:55</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='57' class='' max='444' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.84% [57/444 00:56<06:26 0.4974]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-eefad8ef66e4> in <module>
# ----> 1 learn.fit_one_cycle(12, lr_max=slice(8e-3, 1e-2))
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#     111     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     112               'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 113     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#     114
#     115 # Cell
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     219             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     220             self.n_epoch = n_epoch
# --> 221             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     222
#     223     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_fit(self)
#     210         for epoch in range(self.n_epoch):
#     211             self.epoch=epoch
# --> 212             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     213
#     214     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_epoch(self)
#     204
#     205     def _do_epoch(self):
# --> 206         self._do_epoch_train()
#     207         self._do_epoch_validate()
#     208
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_epoch_train(self)
#     196     def _do_epoch_train(self):
#     197         self.dl = self.dls.train
# --> 198         self._with_events(self.all_batches, 'train', CancelTrainException)
#     199
#     200     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in all_batches(self)
#     167     def all_batches(self):
#     168         self.n_iter = len(self.dl)
# --> 169         for o in enumerate(self.dl): self.one_batch(*o)
#     170
#     171     def _do_one_batch(self):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in one_batch(self, i, b)
#     192         b = self._set_device(b)
#     193         self._split(b)
# --> 194         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     195
#     196     def _do_epoch_train(self):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/learner.py in _do_one_batch(self)
#     178         if not self.training or not len(self.yb): return
#     179         self('before_backward')
# --> 180         self.loss_grad.backward()
#     181         self._with_events(self.opt.step, 'step', CancelStepException)
#     182         self.opt.zero_grad()
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     218                 gradient=gradient,
#     219                 retain_graph=retain_graph,
# --> 220                 create_graph=create_graph)
#     221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1058         # Use `public_api` instead of `implementation` so __torch_function__
#    1059         # implementations can do equality/identity comparisons.
# -> 1060         result = overloaded_arg.__torch_function__(public_api, types, args, kwargs)
#    1061
#    1062         if result is not NotImplemented:
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/fastai/torch_core.py in __torch_function__(self, func, types, args, kwargs)
#     338         convert=False
#     339         if _torch_handled(args, self._opt, func): convert,types = type(self),(torch.Tensor,)
# --> 340         res = super().__torch_function__(func, types, args=args, kwargs=kwargs)
#     341         if convert: res = convert(res)
#     342         if isinstance(res, TensorBase): res.set_meta(self, as_copy=True)
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/tensor.py in __torch_function__(cls, func, types, args, kwargs)
#     993
#     994         with _C.DisableTorchFunction():
# --> 995             ret = func(*args, **kwargs)
#     996             return _convert(ret, cls)
#     997
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
learn.fit_one_cycle(21, lr_max=slice(1e-6,3.981071586167673e-06))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.037874</td>
#       <td>0.070623</td>
#       <td>0.945190</td>
#       <td>0.869055</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.037984</td>
#       <td>0.070666</td>
#       <td>0.943897</td>
#       <td>0.868797</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037011</td>
#       <td>0.071059</td>
#       <td>0.941889</td>
#       <td>0.868439</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.038431</td>
#       <td>0.071733</td>
#       <td>0.939917</td>
#       <td>0.868029</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.037087</td>
#       <td>0.071323</td>
#       <td>0.940441</td>
#       <td>0.868079</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.037160</td>
#       <td>0.072033</td>
#       <td>0.940344</td>
#       <td>0.867942</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.035752</td>
#       <td>0.072776</td>
#       <td>0.940029</td>
#       <td>0.867858</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.037448</td>
#       <td>0.072814</td>
#       <td>0.940238</td>
#       <td>0.867861</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.037692</td>
#       <td>0.073264</td>
#       <td>0.939324</td>
#       <td>0.867652</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.036474</td>
#       <td>0.073398</td>
#       <td>0.939518</td>
#       <td>0.867601</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.037144</td>
#       <td>0.073811</td>
#       <td>0.938988</td>
#       <td>0.867558</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.037952</td>
#       <td>0.074210</td>
#       <td>0.939051</td>
#       <td>0.867503</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0
td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.035432</td>
#       <td>0.054096</td>
#       <td>0.908104</td>
#       <td>0.865265</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.033047</td>
#       <td>0.055349</td>
#       <td>0.917146</td>
#       <td>0.867510</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.033844</td>
#       <td>0.055619</td>
#       <td>0.909283</td>
#       <td>0.865354</td>
#       <td>07:57</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.035235</td>
#       <td>0.055466</td>
#       <td>0.912819</td>
#       <td>0.866111</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.033512</td>
#       <td>0.055913</td>
#       <td>0.912806</td>
#       <td>0.866009</td>
#       <td>07:56</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.032144</td>
#       <td>0.056040</td>
#       <td>0.912573</td>
#       <td>0.865957</td>
#       <td>07:56</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results

# %%
learn.show_results()

# %%
interp = SegmentationInterpretation.from_learner(learn)
interp.plot_top_losses(k=3)

# %% [markdown]
# ### Save model

# %%
learn.export('dense_unet_model.pkl')

# %%
## Measure

# %%
def calc_metrics (gt, pred, heading, short=True): 
    diff = gt - (pred *2)
    fn = (diff== 1).sum()
    tp = (diff==-1).sum()
    fp = (diff==-2).sum()
    tn = (diff== 0).sum()
    p  = tp / (tp + fp)  # precision 
    r  = tp / (tp + fn)  # recall 
    f1 = 2*p*r/(p+r)     # F1 score
    print(heading)
    if not short: 
        print('FN - Green  - (Blood vessel missed):                  ' + str(fn) )
        print('TP - Yellow - (Correctly classified as blood vessel): ' + str(tp) )
        print('FP - Red    - (Wrongly classified as blood vessel):   ' + str(fp) )
        print('TN - Opaque - (Correctly classified as background):   ' + str(tn) )
        print('***************************************************************')
        print('Total pixel number:                                   ' + str(fn+tp+fp+tn))
        print('    ')
    print('Precision:   ' + str(np.round(100*p,2))+'%')
    print('Recall:      ' + str(np.round(100*r,2))+'%')
    print('F1 Score:    ' + str(np.round(100*2*p*r/(p+r),2))+'%')
    print('    ')

# %%
calc_metrics(gt_trn,pred_trn,'Overall Performance across all training data')

# %%
def f1_loss(y_true:torch.Tensor, y_pred:torch.Tensor, is_training=False) -> torch.Tensor:
    '''Calculate F1 score. Can work with gpu tensors
    
    The original implmentation is written by Michal Haltuf on Kaggle.
    
    Returns
    -------
    torch.Tensor
        `ndim` == 1. 0 <= val <= 1
    
    Reference
    ---------
    - https://www.kaggle.com/rejpalcz/best-loss-function-for-f1-score-metric
    - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score
    - https://discuss.pytorch.org/t/calculating-precision-recall-and-f1-score-in-case-of-multi-label-classification/28265/6
    
    '''
    assert y_true.ndim == 1
    assert y_pred.ndim == 1 or y_pred.ndim == 2
    
    if y_pred.ndim == 2:
        y_pred = y_pred.argmax(dim=1)
        
    
    tp = (y_true * y_pred).sum().to(torch.float32)
    tn = ((1 - y_true) * (1 - y_pred)).sum().to(torch.float32)
    fp = ((1 - y_true) * y_pred).sum().to(torch.float32)
    fn = (y_true * (1 - y_pred)).sum().to(torch.float32)
    
    epsilon = 1e-7
    
    precision = tp / (tp + fp + epsilon)
    recall = tp / (tp + fn + epsilon)
    
    f1 = 2* (precision*recall) / (precision + recall + epsilon)
    f1.requires_grad = is_training
    return f1
