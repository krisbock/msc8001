# %%
# %matplotlib inline

# %%
from fastai.vision.all import *
#hide
from fastbook import *

# %%
path = Path("../data/usq/test/images")
#path = Path("../data/usq/mra_mip")

# %%
def get_msk(fname):
    "Grab a mask from a `filename` and adjust the pixels based on `pix2class`"
    fn = str(fname).replace('images','masks')
    msk = np.array(PILMask.create(fn))
    msk = (msk > 100)
    msk = (msk * 1).astype(np.uint8)
    return PILMask.create(msk)

# %%
codes = ['Background', 'CV']

# %%
#get_y = lambda o: get_msk(o)
def get_y(o):
    return get_msk(o)

# %%
dblock = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=get_image_files,
                   splitter=RandomSplitter(),
                   get_y=get_y,
                   #item_tfms=Resize(320),
                   item_tfms=Resize(224),
                   batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
dblock = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=get_image_files,
                   splitter=None,
                   get_y=get_y,
                   #item_tfms=Resize(320),
                   item_tfms=Resize(224),
                   batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
#dls = dblock.dataloaders(path, bs=4) # for dense
dls = dblock.dataloaders(path, bs=8) # for unet

# %%
dsets = dblock.datasets(path)

# %%
fnames = get_image_files(path)

# %%
## load model

# %%
import sys
sys.path.append('/home/msadmin/notebooks/msc8001/src')
from dense_unet import *
from fastai import *
# Out:
# 2021-10-11 21:32:16,774 util_log.py[147] INFO Start the program at:msdsvm, 10.0.0.4, with:Load module
# Adjust wk folder for notebook failed

# %%
learn = load_learner('base_unet_model.pkl')

# %%
learn = load_learner('dense_unet_model.pkl')

# %%
#preds = learn.get_preds(dl=dls.train)

# %%
test_files = get_image_files(path) 
test_dl = learn.dls.test_dl(test_files, with_labels=True)
preds = learn.get_preds(dl=test_dl)

# %%
def calc_metrics (gt, pred, heading, short=True): 
    diff = gt - (pred *2)
    fn = (diff== 1).sum()
    tp = (diff==-1).sum()
    fp = (diff==-2).sum()
    tn = (diff== 0).sum()
    p  = tp / (tp + fp)  # precision 
    r  = tp / (tp + fn)  # recall 
    f1 = 2*p*r/(p+r)     # F1 score
    #print(heading)
    if not short: 
        print('FN - Green  - (Blood vessel missed):                  ' + str(fn) )
        print('TP - Yellow - (Correctly classified as blood vessel): ' + str(tp) )
        print('FP - Red    - (Wrongly classified as blood vessel):   ' + str(fp) )
        print('TN - Opaque - (Correctly classified as background):   ' + str(tn) )
        print('***************************************************************')
        print('Total pixel number:                                   ' + str(fn+tp+fp+tn))
        print('    ')
    #print('Precision:   ' + str(np.round(100*p,2))+'%')
    #print('Recall:      ' + str(np.round(100*r,2))+'%')
    #print('F1 Score:    ' + str(np.round(100*2*p*r/(p+r),2))+'%')
    #print('    ')
    # work out IoU
    intersection = np.logical_and(gt, pred)
    union = np.logical_or(gt, pred)
    iou_score = np.sum(intersection) / np.sum(union)
    return(fn, tp, fp, tn, np.round(100*p,2), np.round(100*r,2), np.round(100*f1,2), iou_score)

# %%
tot_fn = tot_tp = tot_fp = tot_tn = tot_p = tot_r = tot_f1 = 0
for index, item in enumerate(preds[0]):
    y_hat = array(preds[0][index].argmax(dim=0))
    y_true = array(test_dl.dataset[index][1])
    fn, tp, fp, tn, p, r, f1 = calc_metrics(y_true, y_hat, str(test_files[index]), True)
    #print(tot_fn, tot_tp, tot_fp, tot_tn, tot_p, tot_r, tot_f1)
    tot_fn += fn
    tot_tp += tp
    tot_fp += fp
    tot_tn += tn
    tot_p += p
    tot_r += r
    tot_f1 += f1

# %%
# first run

# %%
print(tot_f1 / len(preds[0]))
print(tot_p / len(preds[0]))
print(tot_r / len(preds[0]))
# Out:
# 56.13624999999999
# 59.45258620689659
# 62.5423275862069

# %%
# second run - longer

# %%
print(tot_f1 / len(preds[0]))
print(tot_p / len(preds[0]))
print(tot_r / len(preds[0]))
# Out:
# 49.22728448275864
# 50.49495689655177
# 54.332112068965486

# %%
# third optimised on 42 epochs

# %%
learn = load_learner('dense_unet_model.pkl')

# %%
test_files = get_image_files(path) 
test_dl = learn.dls.test_dl(test_files, with_labels=True)
preds = learn.get_preds(dl=test_dl)

# %%
print(tot_f1 / len(preds[0]))
print(tot_p / len(preds[0]))
print(tot_r / len(preds[0]))
# Out:
# 42.711250000000014
# 50.74530172413793
# 41.516077586206926

# %%
# third run on MNI_0591

# %%
test_files = get_image_files(path) 
test_dl = learn.dls.test_dl(test_files, with_labels=True)
preds = learn.get_preds(dl=test_dl)

# %%
print(tot_fn, tot_tp, tot_fp, tot_tn, tot_p, tot_r, tot_f1)
# Out:
# 119876 1453113 265310 23454501 20698.72 23181.98 21056.91000000001

# %%
print(tot_f1 / len(preds[0]))
print(tot_p / len(preds[0]))
print(tot_r / len(preds[0]))
# Out:
# 85.2506477732794
# 83.80048582995951
# 93.85417004048583

# %%
# run across dataset

# %%
def output(predictions, test_dl, test_files):
    tot_fn = tot_tp = tot_fp = tot_tn = tot_p = tot_r = tot_f1 = 0
    for index, item in enumerate(predictions[0]):
        y_hat = array(predictions[0][index].argmax(dim=0))
        y_true = array(test_dl.dataset[index][1])
        fn, tp, fp, tn, p, r, f1, iou = calc_metrics(y_true, y_hat, str(test_files[index]), True)
        #print(tot_fn, tot_tp, tot_fp, tot_tn, tot_p, tot_r, tot_f1)
        tot_fn += fn
        tot_tp += tp
        tot_fp += fp
        tot_tn += tn
        tot_p += p
        tot_r += r
        tot_f1 += f1
    return(tot_p, tot_r, tot_f1, iou)

# %%
def one_off(mra):
    for i in mra:
        path = Path(f'../data/usq/oneoff/{i}/images')
        test_files = get_image_files(path) 
        test_dl = learn.dls.test_dl(test_files, with_labels=True)
        preds = learn.get_preds(dl=test_dl)
        torch.save((preds[0]), f'../data/usq/results/{i}.pt')
        print(f'Results for {i}:')
        precision, recall, f1, iou = output(preds, test_dl, test_files)
        print(f'Precision: {precision/len(preds[0])} Recall: {recall/len(preds[0])} F1 Score: {f1/len(preds[0])} IoU: {iou}')

# %%
one_off(['MNI_0590', 'MNI_0591', 'MNI_0592', 'MNI_0640', 'MNI_0643', 'MNI_0648', 'MNI_0656', 'MNI_0657', 'MNI_0663'])
# Out:
# Results for MNI_0590:
# Precision: 81.3402024291498 Recall: 89.81165991902837 F1 Score: 82.34939271255062 IoU: 0.3839124839124839
# Results for MNI_0591:
# Precision: 80.70506072874493 Recall: 89.26149797570847 F1 Score: 81.44234817813765 IoU: 0.7646307477937762
# Results for MNI_0592:
# Precision: 80.62461538461535 Recall: 89.90692307692314 F1 Score: 81.73020242914983 IoU: 0.862007623888183
# Results for MNI_0640:
# Precision: 80.93902834008095 Recall: 89.29149797570844 F1 Score: 81.81805668016187 IoU: 0.8334284084426697
# Results for MNI_0643:
# Precision: 81.8521862348178 Recall: 89.81659919028341 F1 Score: 82.58182186234814 IoU: 0.11893484896326703
# Results for MNI_0648:
# Precision: 82.34700404858299 Recall: 90.75493927125511 F1 Score: 83.48267206477743 IoU: 0.73138784551671
# Results for MNI_0656:
# Precision: 85.11882591093114 Recall: 92.6270850202429 F1 Score: 86.4451821862348 IoU: 0.8548408400475499
# Results for MNI_0657:
# ...

# %%
one_off(['MNI_0664'])
# Out:
# Results for MNI_0664:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6affcd9b3aaa> in <module>
# ----> 1 one_off(['MNI_0664'])
#
# <ipython-input-13-019e722f5ef9> in one_off(mra)
#       7         torch.save((preds[0]), f'../data/usq/results/{i}.pt')
#       8         print(f'Results for {i}:')
# ----> 9         precision, recall, f1, iou = output(preds, test_dl, test_files)
#      10         print(f'Precision: {precision/len(preds[0])} Recall: {recall/len(preds[0])} F1 Score: {f1/len(preds[0])} IoU: {iou}')
#
# <ipython-input-12-ea1a7027ba00> in output(predictions, test_dl, test_files)
#       4         y_hat = array(predictions[0][index].argmax(dim=0))
#       5         y_true = array(test_dl.dataset[index][1])
# ----> 6         fn, tp, fp, tn, p, r, f1, iou = calc_metrics(y_true, y_hat, str(test_files[index]), True)
# ...

# %%
tpath = Path(f'../data/usq/oneoff/MNI_0664/images')
ttest_files = get_image_files(tpath) 
ttest_dl = learn.dls.test_dl(ttest_files, with_labels=True)
tpreds = learn.get_preds(dl=ttest_dl)

# %%
tpreds[0].shape
# Out:
# torch.Size([232, 2, 224, 224])

# %%
ttest_dl.dataset
# Out:
# (#232) [(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320),(PILImage mode=RGB size=320x320, PILMask mode=L size=320x320)...]

# %%
# just run results
def just_results(mra):
    for i in mra:
        path = Path(f'../data/usq/oneoff/{i}/images')
        test_files = get_image_files(path) 
        test_dl = learn.dls.test_dl(test_files, with_labels=True)
        preds = torch.load(f'../data/usq/results/{i}.pt')
        print(f'Results for {i}:')
        precision, recall, f1 = output(preds, test_dl, test_files)
        print(f'Precision: {precision/len(preds[0])} Recall: {recall/len(preds[0])} F1 Score: {f1/len(preds[0])}')

# %%
just_results(['MNI_0592'])
# Out:
# Results for MNI_0592:
# Precision: nan Recall: nan F1 Score: nan

# %%
preds = torch.load(f'../data/usq/results/MNI_0592.pt')

# %%
path = Path(f'../data/usq/oneoff/MNI_0592/images')
test_files = get_image_files(path) 
test_dl = learn.dls.test_dl(test_files, with_labels=True)
#preds = learn.get_preds(dl=test_dl)
preds = torch.load(f'../data/usq/results/MNI_0592.pt')
precision, recall, f1, iou = output(preds, test_dl, test_files)
print(f'Precision: {precision/len(preds[0])} Recall: {recall/len(preds[0])} F1 Score: {f1/len(preds[0])}')
# Out:
# Precision: nan Recall: nan F1 Score: nan

# %%
preds[0]
# Out:
# torch.Size([2, 320, 320])

# %%
path = Path(f'../data/usq/oneoff/MNI_0592/images')
test_files = get_image_files(path) 
test_dl = learn.dls.test_dl(test_files, with_labels=True)
preds = learn.get_preds(dl=test_dl)
precision, recall, f1 = output(preds)
print(f'Precision: {precision/len(preds[0])} Recall: {recall/len(preds[0])} F1 Score: {f1/len(preds[0])}')

# %%
# save preds
path = Path(f'../data/usq/results/')
os.makedirs(path, exist_ok=True)
torch.save((preds[0]), path / 'MNI_0592.pt')

# %%
y_hat = array(preds[0][0].argmax(dim=0))
y_true = array(test_dl.dataset[0][1])

# %%
y_hat.shape
# Out:
# (320,)

# %%
y_true.shape
# Out:
# (320, 320)

# %%
        fn, tp, fp, tn, p, r, f1 = calc_metrics(y_true, y_hat, str(test_files[index]), True)
        #print(tot_fn, tot_tp, tot_fp, tot_tn, tot_p, tot_r, tot_f1)
        tot_fn += fn
        tot_tp += tp
        tot_fp += fp
        tot_tn += tn
        tot_p += p
        tot_r += r
        tot_f1 += f1
    return(tot_p, tot_r, tot_f1)

# %%
def f1_loss(y_true:torch.Tensor, y_pred:torch.Tensor, is_training=False) -> torch.Tensor:
    '''Calculate F1 score. Can work with gpu tensors
    
    The original implmentation is written by Michal Haltuf on Kaggle.
    
    Returns
    -------
    torch.Tensor
        `ndim` == 1. 0 <= val <= 1
    
    Reference
    ---------
    - https://www.kaggle.com/rejpalcz/best-loss-function-for-f1-score-metric
    - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score
    - https://discuss.pytorch.org/t/calculating-precision-recall-and-f1-score-in-case-of-multi-label-classification/28265/6
    
    '''
    assert y_true.ndim == 1
    assert y_pred.ndim == 1 or y_pred.ndim == 2
    
    if y_pred.ndim == 2:
        y_pred = y_pred.argmax(dim=1)
        
    
    tp = (y_true * y_pred).sum().to(torch.float32)
    tn = ((1 - y_true) * (1 - y_pred)).sum().to(torch.float32)
    fp = ((1 - y_true) * y_pred).sum().to(torch.float32)
    fn = (y_true * (1 - y_pred)).sum().to(torch.float32)
    
    epsilon = 1e-7
    
    precision = tp / (tp + fp + epsilon)
    recall = tp / (tp + fn + epsilon)
    
    f1 = 2* (precision*recall) / (precision + recall + epsilon)
    f1.requires_grad = is_training
    return f1

# %%
import sklearn.metrics as skm

def acc_iou_curves(y_true, y_score):
    fpr, tpr, thresholds = skm.roc_curve(y_true, y_score)
    num_pos = (y_true == 1).sum().item()
    num_neg = len(y_true) - num_pos
    
    fp = fpr * num_neg
    tp = tpr * num_pos
    fn = (1 - tpr) * num_pos
    tn = (1 - fpr) * num_neg
    
    acc = (tp + tn) / (tp + tn + fp + fn)
    iou = tp / (tp + fp + fn)
    return acc, iou, thresholds

# %%
from collections import defaultdict


def valid_stats(patcher, valid_items, valid_preds, ctx_weight_size_pct=0.8):
    tile_name = lambda i: i[0].name.split('_', 1)[0]
    
    preds = defaultdict(list)
    for item, pred in sorted(zip(valid_items, valid_preds)):
        preds[item.name.split('_', 1)[0]].append(pred)
    
    valid_stitched = {}
    for tile, patches in preds.items():
        label = open_image(path_lbl / f'{tile}.tif').data[0]
        stitched = patcher.stitch_patches_pad(patches, ctx_weight_size_pct=ctx_weight_size_pct)[1]
        mask = stitched != 0
        valid_stitched[tile] = label[mask].flatten(), stitched[mask].flatten()
        
    y_true, y_score = zip(*valid_stitched.values())
    acc, iou, thresholds = acc_iou_curves(torch.cat(y_true), torch.cat(y_score))
    max_idx = np.argmax(iou)
    return {
        'max_iou': iou[max_idx],
        'accuracy': acc[max_idx],
        'threshold': thresholds[max_idx],
    }

# %%
str(fname).replace('images','masks')

# %%
# se-large-2
valid_stats(valid_patcher, all_items, all_preds, ctx_weight_size_pct=0.8)

# %%
from mpl_toolkits.mplot3d import Axes3D

def display_3d_image (data_points, cols):
    fig = plt.figure(figsize=(30,30))
    ax = fig.add_subplot(111, projection='3d')
    i = 0
    for dp in data_points.keys():
        ax.scatter(data_points[dp][2], data_points[dp][1], data_points[dp][0], c=cols[i], marker='o',s=0.5)
        i = i + 1

    plt.xlim(0, len(l_seg[1,1,:]))
    plt.ylim(0, len(l_seg[1,:,1]))
    ax.set_xlabel('Image Slices')
    ax.set_ylabel('X Pixel')
    ax.set_zlabel('Y Pixel')

    plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

def display_3d_image (data_points, cols):
    fig = plt.figure(figsize=(30,30))
    ax = fig.add_subplot(111, projection='3d')
    i = 0
    for dp in data_points.keys():
        ax.scatter(data_points[dp][2], data_points[dp][1], data_points[dp][0], c=cols[i], marker='o',s=0.5)
        i = i + 1

    plt.xlim(0, len(data_points[1,1,:]))
    plt.ylim(0, len(data_points[1,:,1]))
    ax.set_xlabel('Image Slices')
    ax.set_ylabel('X Pixel')
    ax.set_zlabel('Y Pixel')

    plt.show()

# %%
import cv2
def load_images (img_dir, file_list, d, h, w): 
    limg = np.ndarray(shape=(d, h, w), dtype=np.uint16)
    i=0
    for f in file_list: 
        img = cv2.imread(os.path.join(img_dir, f))
        limg[i]=img[:,:,0] 
        i=i+1
    return limg

# %%
#pred_dir = '../data/usq/oneoff/MNI_0592/masks'
pred_dir = '../data/usq/oneoff/MNI_0592/masks'
src_dir = '../data/usq/original_mra/MNI_0592'
gt_dir = '../data/usq/manual_segmentation/MNI_0592'

# %%
fnames = os.listdir(img_dir)
sample_3d = load_images(img_dir, fnames, len(fnames), 320, 320)

# %%
l_src_map = np.ndarray(shape=(1, 247, 320, 320), dtype=np.uint16)  
l_seg_map = np.ndarray(shape=(1, 247, 320, 320), dtype=np.uint16)  
l_gt_map  = np.ndarray(shape=(1, 247, 320, 320), dtype=np.uint16)

# %%
load_images(img_dir, os.listdir(gt_dir), len(fnames), 320, 320)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-27735ff1e2c2> in <module>
# ----> 1 load_images(img_dir, os.listdir(gt_dir), len(fnames), 320, 320)
#
# <ipython-input-10-af59b44565ac> in load_images(img_dir, file_list, d, h, w)
#       5     for f in file_list:
#       6         img = cv2.imread(os.path.join(img_dir, f))
# ----> 7         limg[i]=img[:,:,0]
#       8         i=i+1
#       9     return limg
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Read in 3D MRA source data 
l_src_map[0] = load_images(src_dir, os.listdir(src_dir), len(os.listdir(src_dir)), 320, 320)
# construct the nine 2D MRA projections 
#mra_src_2Ds = app.get_2d_mra_src_projs(l_src_map[i]) 
# run the nine unet processes across the image source projections (as trained in Phase 1)
#mra_seg_2Ds = app.get_2d_mra_seg_projs(mra_src_2Ds) 
# Reconstruct the 3D segmented raw image 
#mra_seg_3D_raw = load_images(img_dir, os.listdir(pred_dir), len(fnames), 320, 320)  

#app.reconstruct_3d_segmentation(mra_seg_2Ds,l_src_map[0]).astype(int)
# Do the post processing
l_seg_map[0] = load_images(pred_dir, os.listdir(pred_dir), len(os.listdir(pred_dir)), 320, 320)  
#app.post_processing(mra_seg_3D_raw,l_src_map[i]).astype(int)
# Load the corresponding 3D Ground Truth image 
l_gt_map[0] = np.sign(load_images(gt_dir, os.listdir(gt_dir), len(os.listdir(gt_dir)), 320, 320)).astype(int)

# %%
idx = 0 # set the index of the record that should be visualised 
l_src = l_src_map[idx]
l_seg = l_seg_map[idx]
l_gt  = l_gt_map[idx]

# %%
img = PILImage.create(load_images(gt_dir, os.listdir(gt_dir), len(os.listdir(gt_dir)), 320, 320)[100])
#mask = PILMask.create(str(fnames[0]).replace('images','masks'))
#mask = PILMask.create(str(fnames[0]).replace('mipimages','mipmasks'))
ax = img.show()
#ax = mask.show(ctx=ax)

# %%
plt.imshow(l_seg[100])

# %%
ll = dict()
i = np.equal(l_gt, 1)
ll[0] = np.where(i)

display_3d_image (ll, ['green'])

# %%
load_images(img_dir, fnames, len(fnames), 320, 320).shape
# Out:
# (247, 320, 320)

# %%
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
img = PILImage.create(load_images(img_dir, fnames, len(fnames), 320, 320)[0])
#mask = PILMask.create(str(fnames[0]).replace('images','masks'))
#mask = PILMask.create(str(fnames[0]).replace('mipimages','mipmasks'))
ax = img.show()
#ax = mask.show(ctx=ax)

# %%
plt.imshow(load_images(img_dir, fnames, len(fnames), 320, 320)[0])

# %%
load_images(img_dir, fnames, len(fnames), 320, 320).shape
# Out:
# (247, 320, 320)
