# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastbook import *

# %%
import cv2
import os

# %%
root_dir = "../data/usq/"

# %%
def create_MIP(np_img, slices_num = 15):
    ''' create the mip image from original image, slice_num is the number of 
    slices for maximum intensity projection'''
    img_shape = np_img.shape
    np_mip = np.zeros(img_shape)
    for i in range(img_shape[0]):
        start = max(0, i-slices_num)
        np_mip[i,:,:] = np.amax(np_img[start:i+1],0)
    return np_mip

# %%
def save_images(img_dir, file_list, img_3d_array):
    for i in range(img_3d_array.shape[0]):
        cv2.imwrite(os.path.join(img_dir, file_list[i]), img_3d_array[i, :, :])

# %%
def load_images (img_dir, file_list, d, h, w): 
    limg = np.ndarray(shape=(d, h, w), dtype=np.uint16)
    i=0
    for f in file_list: 
        img = cv2.imread(os.path.join(img_dir, f))
        # convert image to grey 
        #img = convert_image_to_grey(img,h,w)
        # not needed
        #grey_img = np.zeros((h,w), np.uint16)
        #grey_img[:h,:w] = img[:,:,0] 
        #limg[i]=grey_img
        limg[i]=img[:,:,0] 
        i=i+1
    return limg

# %%
def convert_3d_mip(parent_dir, omit, source_dir = 'original_mra', target_dir = 'mra_mip'):
    #do images
    for subdir in os.listdir(os.path.join(parent_dir, source_dir)):
        # leave out MRI for test
        if subdir in omit:
            continue
        full_img_subdir = os.path.join(parent_dir, source_dir, subdir)
        fnames = os.listdir(full_img_subdir)
        img_3d = load_images(full_img_subdir, fnames, len(fnames), 320, 320)
        img_mip = create_MIP(img_3d, slices_num = img_3d.shape[0])
        # create target dir
        tgt_dir =  os.path.join(parent_dir, target_dir, subdir)
        os.makedirs(tgt_dir, exist_ok=True)
        save_images(tgt_dir, fnames, img_mip)

# %%
# this function grabs images/masks from different patient subdirectories and consolidates 
# them into a single folder with consistent naming
def combine(parent_dir, image_src, image_tgt, mask_src, mask_tgt):
    image_srcdir = os.path.join(parent_dir, image_src)
    mask_srcdir = os.path.join(parent_dir, mask_src)
    image_tgtdir = os.path.join(parent_dir, image_tgt)
    mask_tgtdir = os.path.join(parent_dir, mask_tgt)  
    
    os.makedirs(image_tgtdir, exist_ok=True)
    os.makedirs(mask_tgtdir, exist_ok=True)
    
    for subdir in os.scandir(image_srcdir):
        image_list = sorted(os.listdir(subdir))
        mask_list = sorted(os.listdir(os.path.join(mask_srcdir, os.path.basename(subdir))))
        for i in range(len(image_list)):
            if image_list[i].endswith('.jpg'):
                shutil.copy(os.path.join(subdir.path, image_list[i]), os.path.join(image_tgtdir, image_list[i])) 
                shutil.copy(os.path.join(os.path.join(mask_srcdir, os.path.basename(subdir)), mask_list[i]), os.path.join(mask_tgtdir, image_list[i]))

# %%
# convert_3d_mip(root_dir, 'original_mra', 'mra_mip')
# convert_3d_mip(root_dir, 'manual_segmentation',  'mask_mip')

# %%
train_list = ['MNI_0590', 'MNI_0591', 'MNI_0592', 'MNI_0640', 'MNI_0643', 'MNI_0648', 'MNI_0656', 'MNI_0657', 'MNI_0663']
test_list = ['MNI_0664']

# %%
# do training run
convert_3d_mip(root_dir, test_list, 'original_mra', 'train_mra_mip')
convert_3d_mip(root_dir, test_list, 'manual_segmentation',  'train_mask_mip')

# %%
# apply to test set
convert_3d_mip(root_dir, train_list, 'original_mra', 'test_mra_mip')
convert_3d_mip(root_dir, train_list, 'manual_segmentation',  'test_mask_mip')

# %%
# put together in train/test folders with consistent naming for image/mask
combine(root_dir, 'train_mra_mip', 'train/images', 'train_mask_mip', 'train/masks')
combine(root_dir, 'test_mra_mip', 'test/images', 'test_mask_mip', 'test/masks')

# %%
def combine(parent_dir, image_src, image_tgt, mask_src, mask_tgt, mra):
    image_srcdir = os.path.join(parent_dir, image_src)
    mask_srcdir = os.path.join(parent_dir, mask_src)
    #image_tgtdir = os.path.join(parent_dir, image_tgt, mra, 'images')
    #mask_tgtdir = os.path.join(parent_dir, mask_tgt, mra, 'masks')  
    image_tgtdir = os.path.join(parent_dir, image_tgt)
    mask_tgtdir = os.path.join(parent_dir, mask_tgt)
    os.makedirs(image_tgtdir, exist_ok=True)
    os.makedirs(mask_tgtdir, exist_ok=True)
    image_list = sorted(os.listdir(os.path.join(image_srcdir, mra)))
    mask_list = sorted(os.listdir(os.path.join(mask_srcdir, os.path.basename(mra))))
    for i in range(len(image_list)):
        if image_list[i].endswith('.jpg'):
            print(f'copying {os.path.join(image_srcdir, mra, image_list[i])} to {os.path.join(image_tgtdir, image_list[i])}')

            shutil.copy(os.path.join(image_srcdir, mra, image_list[i]), os.path.join(image_tgtdir, image_list[i])) 
            shutil.copy(os.path.join(os.path.join(mask_srcdir, os.path.basename(mra)), mask_list[i]), os.path.join(mask_tgtdir, image_list[i]))

# %%
# one off

# %%
# run for individual
test_list = ['MNI_0590', 'MNI_0591', 'MNI_0592', 'MNI_0640', 'MNI_0643', 'MNI_0648', 'MNI_0656', 'MNI_0657', 'MNI_0663']
#test_list = ['MNI_0664']
for i in test_list:
    combine(root_dir, 'train_mra_mip', f'oneoff/{i}/images', 'train_mask_mip', f'oneoff/{i}/masks', i)
# Out:
# copying ../data/usq/train_mra_mip/MNI_0590/S580900000.jpg to ../data/usq/oneoff/MNI_0590/images/S580900000.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900001.jpg to ../data/usq/oneoff/MNI_0590/images/S580900001.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900002.jpg to ../data/usq/oneoff/MNI_0590/images/S580900002.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900003.jpg to ../data/usq/oneoff/MNI_0590/images/S580900003.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900004.jpg to ../data/usq/oneoff/MNI_0590/images/S580900004.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900005.jpg to ../data/usq/oneoff/MNI_0590/images/S580900005.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900006.jpg to ../data/usq/oneoff/MNI_0590/images/S580900006.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900007.jpg to ../data/usq/oneoff/MNI_0590/images/S580900007.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900008.jpg to ../data/usq/oneoff/MNI_0590/images/S580900008.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900009.jpg to ../data/usq/oneoff/MNI_0590/images/S580900009.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900010.jpg to ../data/usq/oneoff/MNI_0590/images/S580900010.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900011.jpg to ../data/usq/oneoff/MNI_0590/images/S580900011.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900012.jpg to ../data/usq/oneoff/MNI_0590/images/S580900012.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900013.jpg to ../data/usq/oneoff/MNI_0590/images/S580900013.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900014.jpg to ../data/usq/oneoff/MNI_0590/images/S580900014.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900015.jpg to ../data/usq/oneoff/MNI_0590/images/S580900015.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900016.jpg to ../data/usq/oneoff/MNI_0590/images/S580900016.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900017.jpg to ../data/usq/oneoff/MNI_0590/images/S580900017.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900018.jpg to ../data/usq/oneoff/MNI_0590/images/S580900018.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900019.jpg to ../data/usq/oneoff/MNI_0590/images/S580900019.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900020.jpg to ../data/usq/oneoff/MNI_0590/images/S580900020.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900021.jpg to ../data/usq/oneoff/MNI_0590/images/S580900021.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900022.jpg to ../data/usq/oneoff/MNI_0590/images/S580900022.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900023.jpg to ../data/usq/oneoff/MNI_0590/images/S580900023.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900024.jpg to ../data/usq/oneoff/MNI_0590/images/S580900024.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900025.jpg to ../data/usq/oneoff/MNI_0590/images/S580900025.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900026.jpg to ../data/usq/oneoff/MNI_0590/images/S580900026.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900027.jpg to ../data/usq/oneoff/MNI_0590/images/S580900027.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900028.jpg to ../data/usq/oneoff/MNI_0590/images/S580900028.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900029.jpg to ../data/usq/oneoff/MNI_0590/images/S580900029.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900030.jpg to ../data/usq/oneoff/MNI_0590/images/S580900030.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900031.jpg to ../data/usq/oneoff/MNI_0590/images/S580900031.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900032.jpg to ../data/usq/oneoff/MNI_0590/images/S580900032.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900033.jpg to ../data/usq/oneoff/MNI_0590/images/S580900033.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900034.jpg to ../data/usq/oneoff/MNI_0590/images/S580900034.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900035.jpg to ../data/usq/oneoff/MNI_0590/images/S580900035.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900036.jpg to ../data/usq/oneoff/MNI_0590/images/S580900036.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900037.jpg to ../data/usq/oneoff/MNI_0590/images/S580900037.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900038.jpg to ../data/usq/oneoff/MNI_0590/images/S580900038.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900039.jpg to ../data/usq/oneoff/MNI_0590/images/S580900039.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900040.jpg to ../data/usq/oneoff/MNI_0590/images/S580900040.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900041.jpg to ../data/usq/oneoff/MNI_0590/images/S580900041.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900042.jpg to ../data/usq/oneoff/MNI_0590/images/S580900042.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900043.jpg to ../data/usq/oneoff/MNI_0590/images/S580900043.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900044.jpg to ../data/usq/oneoff/MNI_0590/images/S580900044.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900045.jpg to ../data/usq/oneoff/MNI_0590/images/S580900045.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900046.jpg to ../data/usq/oneoff/MNI_0590/images/S580900046.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900047.jpg to ../data/usq/oneoff/MNI_0590/images/S580900047.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900048.jpg to ../data/usq/oneoff/MNI_0590/images/S580900048.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900049.jpg to ../data/usq/oneoff/MNI_0590/images/S580900049.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900050.jpg to ../data/usq/oneoff/MNI_0590/images/S580900050.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900051.jpg to ../data/usq/oneoff/MNI_0590/images/S580900051.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900052.jpg to ../data/usq/oneoff/MNI_0590/images/S580900052.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900053.jpg to ../data/usq/oneoff/MNI_0590/images/S580900053.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900054.jpg to ../data/usq/oneoff/MNI_0590/images/S580900054.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900055.jpg to ../data/usq/oneoff/MNI_0590/images/S580900055.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900056.jpg to ../data/usq/oneoff/MNI_0590/images/S580900056.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900057.jpg to ../data/usq/oneoff/MNI_0590/images/S580900057.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900058.jpg to ../data/usq/oneoff/MNI_0590/images/S580900058.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900059.jpg to ../data/usq/oneoff/MNI_0590/images/S580900059.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900060.jpg to ../data/usq/oneoff/MNI_0590/images/S580900060.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900061.jpg to ../data/usq/oneoff/MNI_0590/images/S580900061.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900062.jpg to ../data/usq/oneoff/MNI_0590/images/S580900062.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900063.jpg to ../data/usq/oneoff/MNI_0590/images/S580900063.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900064.jpg to ../data/usq/oneoff/MNI_0590/images/S580900064.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900065.jpg to ../data/usq/oneoff/MNI_0590/images/S580900065.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900066.jpg to ../data/usq/oneoff/MNI_0590/images/S580900066.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900067.jpg to ../data/usq/oneoff/MNI_0590/images/S580900067.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900068.jpg to ../data/usq/oneoff/MNI_0590/images/S580900068.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900069.jpg to ../data/usq/oneoff/MNI_0590/images/S580900069.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900070.jpg to ../data/usq/oneoff/MNI_0590/images/S580900070.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900071.jpg to ../data/usq/oneoff/MNI_0590/images/S580900071.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900072.jpg to ../data/usq/oneoff/MNI_0590/images/S580900072.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900073.jpg to ../data/usq/oneoff/MNI_0590/images/S580900073.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900074.jpg to ../data/usq/oneoff/MNI_0590/images/S580900074.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900075.jpg to ../data/usq/oneoff/MNI_0590/images/S580900075.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900076.jpg to ../data/usq/oneoff/MNI_0590/images/S580900076.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900077.jpg to ../data/usq/oneoff/MNI_0590/images/S580900077.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900078.jpg to ../data/usq/oneoff/MNI_0590/images/S580900078.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900079.jpg to ../data/usq/oneoff/MNI_0590/images/S580900079.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900080.jpg to ../data/usq/oneoff/MNI_0590/images/S580900080.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900081.jpg to ../data/usq/oneoff/MNI_0590/images/S580900081.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900082.jpg to ../data/usq/oneoff/MNI_0590/images/S580900082.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900083.jpg to ../data/usq/oneoff/MNI_0590/images/S580900083.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900084.jpg to ../data/usq/oneoff/MNI_0590/images/S580900084.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900085.jpg to ../data/usq/oneoff/MNI_0590/images/S580900085.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900086.jpg to ../data/usq/oneoff/MNI_0590/images/S580900086.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900087.jpg to ../data/usq/oneoff/MNI_0590/images/S580900087.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900088.jpg to ../data/usq/oneoff/MNI_0590/images/S580900088.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900089.jpg to ../data/usq/oneoff/MNI_0590/images/S580900089.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900090.jpg to ../data/usq/oneoff/MNI_0590/images/S580900090.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900091.jpg to ../data/usq/oneoff/MNI_0590/images/S580900091.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900092.jpg to ../data/usq/oneoff/MNI_0590/images/S580900092.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900093.jpg to ../data/usq/oneoff/MNI_0590/images/S580900093.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900094.jpg to ../data/usq/oneoff/MNI_0590/images/S580900094.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900095.jpg to ../data/usq/oneoff/MNI_0590/images/S580900095.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900096.jpg to ../data/usq/oneoff/MNI_0590/images/S580900096.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900097.jpg to ../data/usq/oneoff/MNI_0590/images/S580900097.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900098.jpg to ../data/usq/oneoff/MNI_0590/images/S580900098.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900099.jpg to ../data/usq/oneoff/MNI_0590/images/S580900099.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900100.jpg to ../data/usq/oneoff/MNI_0590/images/S580900100.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900101.jpg to ../data/usq/oneoff/MNI_0590/images/S580900101.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900102.jpg to ../data/usq/oneoff/MNI_0590/images/S580900102.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900103.jpg to ../data/usq/oneoff/MNI_0590/images/S580900103.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900104.jpg to ../data/usq/oneoff/MNI_0590/images/S580900104.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900105.jpg to ../data/usq/oneoff/MNI_0590/images/S580900105.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900106.jpg to ../data/usq/oneoff/MNI_0590/images/S580900106.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900107.jpg to ../data/usq/oneoff/MNI_0590/images/S580900107.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900108.jpg to ../data/usq/oneoff/MNI_0590/images/S580900108.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900109.jpg to ../data/usq/oneoff/MNI_0590/images/S580900109.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900110.jpg to ../data/usq/oneoff/MNI_0590/images/S580900110.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900111.jpg to ../data/usq/oneoff/MNI_0590/images/S580900111.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900112.jpg to ../data/usq/oneoff/MNI_0590/images/S580900112.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900113.jpg to ../data/usq/oneoff/MNI_0590/images/S580900113.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900114.jpg to ../data/usq/oneoff/MNI_0590/images/S580900114.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900115.jpg to ../data/usq/oneoff/MNI_0590/images/S580900115.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900116.jpg to ../data/usq/oneoff/MNI_0590/images/S580900116.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900117.jpg to ../data/usq/oneoff/MNI_0590/images/S580900117.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900118.jpg to ../data/usq/oneoff/MNI_0590/images/S580900118.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900119.jpg to ../data/usq/oneoff/MNI_0590/images/S580900119.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900120.jpg to ../data/usq/oneoff/MNI_0590/images/S580900120.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900121.jpg to ../data/usq/oneoff/MNI_0590/images/S580900121.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900122.jpg to ../data/usq/oneoff/MNI_0590/images/S580900122.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900123.jpg to ../data/usq/oneoff/MNI_0590/images/S580900123.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900124.jpg to ../data/usq/oneoff/MNI_0590/images/S580900124.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900125.jpg to ../data/usq/oneoff/MNI_0590/images/S580900125.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900126.jpg to ../data/usq/oneoff/MNI_0590/images/S580900126.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900127.jpg to ../data/usq/oneoff/MNI_0590/images/S580900127.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900128.jpg to ../data/usq/oneoff/MNI_0590/images/S580900128.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900129.jpg to ../data/usq/oneoff/MNI_0590/images/S580900129.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900130.jpg to ../data/usq/oneoff/MNI_0590/images/S580900130.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900131.jpg to ../data/usq/oneoff/MNI_0590/images/S580900131.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900132.jpg to ../data/usq/oneoff/MNI_0590/images/S580900132.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900133.jpg to ../data/usq/oneoff/MNI_0590/images/S580900133.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900134.jpg to ../data/usq/oneoff/MNI_0590/images/S580900134.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900135.jpg to ../data/usq/oneoff/MNI_0590/images/S580900135.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900136.jpg to ../data/usq/oneoff/MNI_0590/images/S580900136.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900137.jpg to ../data/usq/oneoff/MNI_0590/images/S580900137.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900138.jpg to ../data/usq/oneoff/MNI_0590/images/S580900138.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900139.jpg to ../data/usq/oneoff/MNI_0590/images/S580900139.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900140.jpg to ../data/usq/oneoff/MNI_0590/images/S580900140.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900141.jpg to ../data/usq/oneoff/MNI_0590/images/S580900141.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900142.jpg to ../data/usq/oneoff/MNI_0590/images/S580900142.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900143.jpg to ../data/usq/oneoff/MNI_0590/images/S580900143.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900144.jpg to ../data/usq/oneoff/MNI_0590/images/S580900144.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900145.jpg to ../data/usq/oneoff/MNI_0590/images/S580900145.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900146.jpg to ../data/usq/oneoff/MNI_0590/images/S580900146.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900147.jpg to ../data/usq/oneoff/MNI_0590/images/S580900147.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900148.jpg to ../data/usq/oneoff/MNI_0590/images/S580900148.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900149.jpg to ../data/usq/oneoff/MNI_0590/images/S580900149.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900150.jpg to ../data/usq/oneoff/MNI_0590/images/S580900150.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900151.jpg to ../data/usq/oneoff/MNI_0590/images/S580900151.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900152.jpg to ../data/usq/oneoff/MNI_0590/images/S580900152.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900153.jpg to ../data/usq/oneoff/MNI_0590/images/S580900153.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900154.jpg to ../data/usq/oneoff/MNI_0590/images/S580900154.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900155.jpg to ../data/usq/oneoff/MNI_0590/images/S580900155.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900156.jpg to ../data/usq/oneoff/MNI_0590/images/S580900156.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900157.jpg to ../data/usq/oneoff/MNI_0590/images/S580900157.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900158.jpg to ../data/usq/oneoff/MNI_0590/images/S580900158.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900159.jpg to ../data/usq/oneoff/MNI_0590/images/S580900159.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900160.jpg to ../data/usq/oneoff/MNI_0590/images/S580900160.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900161.jpg to ../data/usq/oneoff/MNI_0590/images/S580900161.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900162.jpg to ../data/usq/oneoff/MNI_0590/images/S580900162.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900163.jpg to ../data/usq/oneoff/MNI_0590/images/S580900163.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900164.jpg to ../data/usq/oneoff/MNI_0590/images/S580900164.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900165.jpg to ../data/usq/oneoff/MNI_0590/images/S580900165.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900166.jpg to ../data/usq/oneoff/MNI_0590/images/S580900166.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900167.jpg to ../data/usq/oneoff/MNI_0590/images/S580900167.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900168.jpg to ../data/usq/oneoff/MNI_0590/images/S580900168.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900169.jpg to ../data/usq/oneoff/MNI_0590/images/S580900169.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900170.jpg to ../data/usq/oneoff/MNI_0590/images/S580900170.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900171.jpg to ../data/usq/oneoff/MNI_0590/images/S580900171.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900172.jpg to ../data/usq/oneoff/MNI_0590/images/S580900172.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900173.jpg to ../data/usq/oneoff/MNI_0590/images/S580900173.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900174.jpg to ../data/usq/oneoff/MNI_0590/images/S580900174.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900175.jpg to ../data/usq/oneoff/MNI_0590/images/S580900175.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900176.jpg to ../data/usq/oneoff/MNI_0590/images/S580900176.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900177.jpg to ../data/usq/oneoff/MNI_0590/images/S580900177.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900178.jpg to ../data/usq/oneoff/MNI_0590/images/S580900178.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900179.jpg to ../data/usq/oneoff/MNI_0590/images/S580900179.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900180.jpg to ../data/usq/oneoff/MNI_0590/images/S580900180.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900181.jpg to ../data/usq/oneoff/MNI_0590/images/S580900181.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900182.jpg to ../data/usq/oneoff/MNI_0590/images/S580900182.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900183.jpg to ../data/usq/oneoff/MNI_0590/images/S580900183.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900184.jpg to ../data/usq/oneoff/MNI_0590/images/S580900184.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900185.jpg to ../data/usq/oneoff/MNI_0590/images/S580900185.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900186.jpg to ../data/usq/oneoff/MNI_0590/images/S580900186.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900187.jpg to ../data/usq/oneoff/MNI_0590/images/S580900187.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900188.jpg to ../data/usq/oneoff/MNI_0590/images/S580900188.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900189.jpg to ../data/usq/oneoff/MNI_0590/images/S580900189.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900190.jpg to ../data/usq/oneoff/MNI_0590/images/S580900190.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900191.jpg to ../data/usq/oneoff/MNI_0590/images/S580900191.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900192.jpg to ../data/usq/oneoff/MNI_0590/images/S580900192.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900193.jpg to ../data/usq/oneoff/MNI_0590/images/S580900193.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900194.jpg to ../data/usq/oneoff/MNI_0590/images/S580900194.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900195.jpg to ../data/usq/oneoff/MNI_0590/images/S580900195.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900196.jpg to ../data/usq/oneoff/MNI_0590/images/S580900196.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900197.jpg to ../data/usq/oneoff/MNI_0590/images/S580900197.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900198.jpg to ../data/usq/oneoff/MNI_0590/images/S580900198.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900199.jpg to ../data/usq/oneoff/MNI_0590/images/S580900199.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900200.jpg to ../data/usq/oneoff/MNI_0590/images/S580900200.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900201.jpg to ../data/usq/oneoff/MNI_0590/images/S580900201.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900202.jpg to ../data/usq/oneoff/MNI_0590/images/S580900202.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900203.jpg to ../data/usq/oneoff/MNI_0590/images/S580900203.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900204.jpg to ../data/usq/oneoff/MNI_0590/images/S580900204.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900205.jpg to ../data/usq/oneoff/MNI_0590/images/S580900205.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900206.jpg to ../data/usq/oneoff/MNI_0590/images/S580900206.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900207.jpg to ../data/usq/oneoff/MNI_0590/images/S580900207.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900208.jpg to ../data/usq/oneoff/MNI_0590/images/S580900208.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900209.jpg to ../data/usq/oneoff/MNI_0590/images/S580900209.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900210.jpg to ../data/usq/oneoff/MNI_0590/images/S580900210.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900211.jpg to ../data/usq/oneoff/MNI_0590/images/S580900211.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900212.jpg to ../data/usq/oneoff/MNI_0590/images/S580900212.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900213.jpg to ../data/usq/oneoff/MNI_0590/images/S580900213.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900214.jpg to ../data/usq/oneoff/MNI_0590/images/S580900214.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900215.jpg to ../data/usq/oneoff/MNI_0590/images/S580900215.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900216.jpg to ../data/usq/oneoff/MNI_0590/images/S580900216.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900217.jpg to ../data/usq/oneoff/MNI_0590/images/S580900217.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900218.jpg to ../data/usq/oneoff/MNI_0590/images/S580900218.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900219.jpg to ../data/usq/oneoff/MNI_0590/images/S580900219.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900220.jpg to ../data/usq/oneoff/MNI_0590/images/S580900220.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900221.jpg to ../data/usq/oneoff/MNI_0590/images/S580900221.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900222.jpg to ../data/usq/oneoff/MNI_0590/images/S580900222.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900223.jpg to ../data/usq/oneoff/MNI_0590/images/S580900223.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900224.jpg to ../data/usq/oneoff/MNI_0590/images/S580900224.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900225.jpg to ../data/usq/oneoff/MNI_0590/images/S580900225.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900226.jpg to ../data/usq/oneoff/MNI_0590/images/S580900226.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900227.jpg to ../data/usq/oneoff/MNI_0590/images/S580900227.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900228.jpg to ../data/usq/oneoff/MNI_0590/images/S580900228.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900229.jpg to ../data/usq/oneoff/MNI_0590/images/S580900229.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900230.jpg to ../data/usq/oneoff/MNI_0590/images/S580900230.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900231.jpg to ../data/usq/oneoff/MNI_0590/images/S580900231.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900232.jpg to ../data/usq/oneoff/MNI_0590/images/S580900232.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900233.jpg to ../data/usq/oneoff/MNI_0590/images/S580900233.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900234.jpg to ../data/usq/oneoff/MNI_0590/images/S580900234.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900235.jpg to ../data/usq/oneoff/MNI_0590/images/S580900235.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900236.jpg to ../data/usq/oneoff/MNI_0590/images/S580900236.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900237.jpg to ../data/usq/oneoff/MNI_0590/images/S580900237.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900238.jpg to ../data/usq/oneoff/MNI_0590/images/S580900238.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900239.jpg to ../data/usq/oneoff/MNI_0590/images/S580900239.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900240.jpg to ../data/usq/oneoff/MNI_0590/images/S580900240.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900241.jpg to ../data/usq/oneoff/MNI_0590/images/S580900241.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900242.jpg to ../data/usq/oneoff/MNI_0590/images/S580900242.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900243.jpg to ../data/usq/oneoff/MNI_0590/images/S580900243.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900244.jpg to ../data/usq/oneoff/MNI_0590/images/S580900244.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900245.jpg to ../data/usq/oneoff/MNI_0590/images/S580900245.jpg
# copying ../data/usq/train_mra_mip/MNI_0590/S580900246.jpg to ../data/usq/oneoff/MNI_0590/images/S580900246.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960000.jpg to ../data/usq/oneoff/MNI_0591/images/S580960000.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960001.jpg to ../data/usq/oneoff/MNI_0591/images/S580960001.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960002.jpg to ../data/usq/oneoff/MNI_0591/images/S580960002.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960003.jpg to ../data/usq/oneoff/MNI_0591/images/S580960003.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960004.jpg to ../data/usq/oneoff/MNI_0591/images/S580960004.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960005.jpg to ../data/usq/oneoff/MNI_0591/images/S580960005.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960006.jpg to ../data/usq/oneoff/MNI_0591/images/S580960006.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960007.jpg to ../data/usq/oneoff/MNI_0591/images/S580960007.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960008.jpg to ../data/usq/oneoff/MNI_0591/images/S580960008.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960009.jpg to ../data/usq/oneoff/MNI_0591/images/S580960009.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960010.jpg to ../data/usq/oneoff/MNI_0591/images/S580960010.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960011.jpg to ../data/usq/oneoff/MNI_0591/images/S580960011.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960012.jpg to ../data/usq/oneoff/MNI_0591/images/S580960012.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960013.jpg to ../data/usq/oneoff/MNI_0591/images/S580960013.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960014.jpg to ../data/usq/oneoff/MNI_0591/images/S580960014.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960015.jpg to ../data/usq/oneoff/MNI_0591/images/S580960015.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960016.jpg to ../data/usq/oneoff/MNI_0591/images/S580960016.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960017.jpg to ../data/usq/oneoff/MNI_0591/images/S580960017.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960018.jpg to ../data/usq/oneoff/MNI_0591/images/S580960018.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960019.jpg to ../data/usq/oneoff/MNI_0591/images/S580960019.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960020.jpg to ../data/usq/oneoff/MNI_0591/images/S580960020.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960021.jpg to ../data/usq/oneoff/MNI_0591/images/S580960021.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960022.jpg to ../data/usq/oneoff/MNI_0591/images/S580960022.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960023.jpg to ../data/usq/oneoff/MNI_0591/images/S580960023.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960024.jpg to ../data/usq/oneoff/MNI_0591/images/S580960024.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960025.jpg to ../data/usq/oneoff/MNI_0591/images/S580960025.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960026.jpg to ../data/usq/oneoff/MNI_0591/images/S580960026.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960027.jpg to ../data/usq/oneoff/MNI_0591/images/S580960027.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960028.jpg to ../data/usq/oneoff/MNI_0591/images/S580960028.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960029.jpg to ../data/usq/oneoff/MNI_0591/images/S580960029.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960030.jpg to ../data/usq/oneoff/MNI_0591/images/S580960030.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960031.jpg to ../data/usq/oneoff/MNI_0591/images/S580960031.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960032.jpg to ../data/usq/oneoff/MNI_0591/images/S580960032.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960033.jpg to ../data/usq/oneoff/MNI_0591/images/S580960033.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960034.jpg to ../data/usq/oneoff/MNI_0591/images/S580960034.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960035.jpg to ../data/usq/oneoff/MNI_0591/images/S580960035.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960036.jpg to ../data/usq/oneoff/MNI_0591/images/S580960036.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960037.jpg to ../data/usq/oneoff/MNI_0591/images/S580960037.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960038.jpg to ../data/usq/oneoff/MNI_0591/images/S580960038.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960039.jpg to ../data/usq/oneoff/MNI_0591/images/S580960039.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960040.jpg to ../data/usq/oneoff/MNI_0591/images/S580960040.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960041.jpg to ../data/usq/oneoff/MNI_0591/images/S580960041.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960042.jpg to ../data/usq/oneoff/MNI_0591/images/S580960042.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960043.jpg to ../data/usq/oneoff/MNI_0591/images/S580960043.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960044.jpg to ../data/usq/oneoff/MNI_0591/images/S580960044.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960045.jpg to ../data/usq/oneoff/MNI_0591/images/S580960045.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960046.jpg to ../data/usq/oneoff/MNI_0591/images/S580960046.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960047.jpg to ../data/usq/oneoff/MNI_0591/images/S580960047.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960048.jpg to ../data/usq/oneoff/MNI_0591/images/S580960048.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960049.jpg to ../data/usq/oneoff/MNI_0591/images/S580960049.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960050.jpg to ../data/usq/oneoff/MNI_0591/images/S580960050.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960051.jpg to ../data/usq/oneoff/MNI_0591/images/S580960051.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960052.jpg to ../data/usq/oneoff/MNI_0591/images/S580960052.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960053.jpg to ../data/usq/oneoff/MNI_0591/images/S580960053.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960054.jpg to ../data/usq/oneoff/MNI_0591/images/S580960054.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960055.jpg to ../data/usq/oneoff/MNI_0591/images/S580960055.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960056.jpg to ../data/usq/oneoff/MNI_0591/images/S580960056.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960057.jpg to ../data/usq/oneoff/MNI_0591/images/S580960057.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960058.jpg to ../data/usq/oneoff/MNI_0591/images/S580960058.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960059.jpg to ../data/usq/oneoff/MNI_0591/images/S580960059.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960060.jpg to ../data/usq/oneoff/MNI_0591/images/S580960060.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960061.jpg to ../data/usq/oneoff/MNI_0591/images/S580960061.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960062.jpg to ../data/usq/oneoff/MNI_0591/images/S580960062.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960063.jpg to ../data/usq/oneoff/MNI_0591/images/S580960063.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960064.jpg to ../data/usq/oneoff/MNI_0591/images/S580960064.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960065.jpg to ../data/usq/oneoff/MNI_0591/images/S580960065.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960066.jpg to ../data/usq/oneoff/MNI_0591/images/S580960066.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960067.jpg to ../data/usq/oneoff/MNI_0591/images/S580960067.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960068.jpg to ../data/usq/oneoff/MNI_0591/images/S580960068.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960069.jpg to ../data/usq/oneoff/MNI_0591/images/S580960069.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960070.jpg to ../data/usq/oneoff/MNI_0591/images/S580960070.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960071.jpg to ../data/usq/oneoff/MNI_0591/images/S580960071.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960072.jpg to ../data/usq/oneoff/MNI_0591/images/S580960072.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960073.jpg to ../data/usq/oneoff/MNI_0591/images/S580960073.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960074.jpg to ../data/usq/oneoff/MNI_0591/images/S580960074.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960075.jpg to ../data/usq/oneoff/MNI_0591/images/S580960075.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960076.jpg to ../data/usq/oneoff/MNI_0591/images/S580960076.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960077.jpg to ../data/usq/oneoff/MNI_0591/images/S580960077.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960078.jpg to ../data/usq/oneoff/MNI_0591/images/S580960078.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960079.jpg to ../data/usq/oneoff/MNI_0591/images/S580960079.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960080.jpg to ../data/usq/oneoff/MNI_0591/images/S580960080.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960081.jpg to ../data/usq/oneoff/MNI_0591/images/S580960081.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960082.jpg to ../data/usq/oneoff/MNI_0591/images/S580960082.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960083.jpg to ../data/usq/oneoff/MNI_0591/images/S580960083.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960084.jpg to ../data/usq/oneoff/MNI_0591/images/S580960084.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960085.jpg to ../data/usq/oneoff/MNI_0591/images/S580960085.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960086.jpg to ../data/usq/oneoff/MNI_0591/images/S580960086.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960087.jpg to ../data/usq/oneoff/MNI_0591/images/S580960087.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960088.jpg to ../data/usq/oneoff/MNI_0591/images/S580960088.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960089.jpg to ../data/usq/oneoff/MNI_0591/images/S580960089.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960090.jpg to ../data/usq/oneoff/MNI_0591/images/S580960090.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960091.jpg to ../data/usq/oneoff/MNI_0591/images/S580960091.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960092.jpg to ../data/usq/oneoff/MNI_0591/images/S580960092.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960093.jpg to ../data/usq/oneoff/MNI_0591/images/S580960093.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960094.jpg to ../data/usq/oneoff/MNI_0591/images/S580960094.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960095.jpg to ../data/usq/oneoff/MNI_0591/images/S580960095.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960096.jpg to ../data/usq/oneoff/MNI_0591/images/S580960096.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960097.jpg to ../data/usq/oneoff/MNI_0591/images/S580960097.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960098.jpg to ../data/usq/oneoff/MNI_0591/images/S580960098.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960099.jpg to ../data/usq/oneoff/MNI_0591/images/S580960099.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960100.jpg to ../data/usq/oneoff/MNI_0591/images/S580960100.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960101.jpg to ../data/usq/oneoff/MNI_0591/images/S580960101.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960102.jpg to ../data/usq/oneoff/MNI_0591/images/S580960102.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960103.jpg to ../data/usq/oneoff/MNI_0591/images/S580960103.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960104.jpg to ../data/usq/oneoff/MNI_0591/images/S580960104.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960105.jpg to ../data/usq/oneoff/MNI_0591/images/S580960105.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960106.jpg to ../data/usq/oneoff/MNI_0591/images/S580960106.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960107.jpg to ../data/usq/oneoff/MNI_0591/images/S580960107.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960108.jpg to ../data/usq/oneoff/MNI_0591/images/S580960108.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960109.jpg to ../data/usq/oneoff/MNI_0591/images/S580960109.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960110.jpg to ../data/usq/oneoff/MNI_0591/images/S580960110.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960111.jpg to ../data/usq/oneoff/MNI_0591/images/S580960111.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960112.jpg to ../data/usq/oneoff/MNI_0591/images/S580960112.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960113.jpg to ../data/usq/oneoff/MNI_0591/images/S580960113.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960114.jpg to ../data/usq/oneoff/MNI_0591/images/S580960114.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960115.jpg to ../data/usq/oneoff/MNI_0591/images/S580960115.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960116.jpg to ../data/usq/oneoff/MNI_0591/images/S580960116.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960117.jpg to ../data/usq/oneoff/MNI_0591/images/S580960117.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960118.jpg to ../data/usq/oneoff/MNI_0591/images/S580960118.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960119.jpg to ../data/usq/oneoff/MNI_0591/images/S580960119.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960120.jpg to ../data/usq/oneoff/MNI_0591/images/S580960120.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960121.jpg to ../data/usq/oneoff/MNI_0591/images/S580960121.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960122.jpg to ../data/usq/oneoff/MNI_0591/images/S580960122.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960123.jpg to ../data/usq/oneoff/MNI_0591/images/S580960123.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960124.jpg to ../data/usq/oneoff/MNI_0591/images/S580960124.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960125.jpg to ../data/usq/oneoff/MNI_0591/images/S580960125.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960126.jpg to ../data/usq/oneoff/MNI_0591/images/S580960126.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960127.jpg to ../data/usq/oneoff/MNI_0591/images/S580960127.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960128.jpg to ../data/usq/oneoff/MNI_0591/images/S580960128.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960129.jpg to ../data/usq/oneoff/MNI_0591/images/S580960129.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960130.jpg to ../data/usq/oneoff/MNI_0591/images/S580960130.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960131.jpg to ../data/usq/oneoff/MNI_0591/images/S580960131.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960132.jpg to ../data/usq/oneoff/MNI_0591/images/S580960132.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960133.jpg to ../data/usq/oneoff/MNI_0591/images/S580960133.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960134.jpg to ../data/usq/oneoff/MNI_0591/images/S580960134.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960135.jpg to ../data/usq/oneoff/MNI_0591/images/S580960135.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960136.jpg to ../data/usq/oneoff/MNI_0591/images/S580960136.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960137.jpg to ../data/usq/oneoff/MNI_0591/images/S580960137.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960138.jpg to ../data/usq/oneoff/MNI_0591/images/S580960138.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960139.jpg to ../data/usq/oneoff/MNI_0591/images/S580960139.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960140.jpg to ../data/usq/oneoff/MNI_0591/images/S580960140.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960141.jpg to ../data/usq/oneoff/MNI_0591/images/S580960141.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960142.jpg to ../data/usq/oneoff/MNI_0591/images/S580960142.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960143.jpg to ../data/usq/oneoff/MNI_0591/images/S580960143.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960144.jpg to ../data/usq/oneoff/MNI_0591/images/S580960144.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960145.jpg to ../data/usq/oneoff/MNI_0591/images/S580960145.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960146.jpg to ../data/usq/oneoff/MNI_0591/images/S580960146.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960147.jpg to ../data/usq/oneoff/MNI_0591/images/S580960147.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960148.jpg to ../data/usq/oneoff/MNI_0591/images/S580960148.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960149.jpg to ../data/usq/oneoff/MNI_0591/images/S580960149.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960150.jpg to ../data/usq/oneoff/MNI_0591/images/S580960150.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960151.jpg to ../data/usq/oneoff/MNI_0591/images/S580960151.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960152.jpg to ../data/usq/oneoff/MNI_0591/images/S580960152.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960153.jpg to ../data/usq/oneoff/MNI_0591/images/S580960153.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960154.jpg to ../data/usq/oneoff/MNI_0591/images/S580960154.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960155.jpg to ../data/usq/oneoff/MNI_0591/images/S580960155.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960156.jpg to ../data/usq/oneoff/MNI_0591/images/S580960156.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960157.jpg to ../data/usq/oneoff/MNI_0591/images/S580960157.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960158.jpg to ../data/usq/oneoff/MNI_0591/images/S580960158.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960159.jpg to ../data/usq/oneoff/MNI_0591/images/S580960159.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960160.jpg to ../data/usq/oneoff/MNI_0591/images/S580960160.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960161.jpg to ../data/usq/oneoff/MNI_0591/images/S580960161.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960162.jpg to ../data/usq/oneoff/MNI_0591/images/S580960162.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960163.jpg to ../data/usq/oneoff/MNI_0591/images/S580960163.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960164.jpg to ../data/usq/oneoff/MNI_0591/images/S580960164.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960165.jpg to ../data/usq/oneoff/MNI_0591/images/S580960165.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960166.jpg to ../data/usq/oneoff/MNI_0591/images/S580960166.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960167.jpg to ../data/usq/oneoff/MNI_0591/images/S580960167.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960168.jpg to ../data/usq/oneoff/MNI_0591/images/S580960168.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960169.jpg to ../data/usq/oneoff/MNI_0591/images/S580960169.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960170.jpg to ../data/usq/oneoff/MNI_0591/images/S580960170.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960171.jpg to ../data/usq/oneoff/MNI_0591/images/S580960171.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960172.jpg to ../data/usq/oneoff/MNI_0591/images/S580960172.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960173.jpg to ../data/usq/oneoff/MNI_0591/images/S580960173.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960174.jpg to ../data/usq/oneoff/MNI_0591/images/S580960174.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960175.jpg to ../data/usq/oneoff/MNI_0591/images/S580960175.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960176.jpg to ../data/usq/oneoff/MNI_0591/images/S580960176.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960177.jpg to ../data/usq/oneoff/MNI_0591/images/S580960177.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960178.jpg to ../data/usq/oneoff/MNI_0591/images/S580960178.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960179.jpg to ../data/usq/oneoff/MNI_0591/images/S580960179.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960180.jpg to ../data/usq/oneoff/MNI_0591/images/S580960180.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960181.jpg to ../data/usq/oneoff/MNI_0591/images/S580960181.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960182.jpg to ../data/usq/oneoff/MNI_0591/images/S580960182.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960183.jpg to ../data/usq/oneoff/MNI_0591/images/S580960183.jpg
# copying ../data/usq/train_mra_mip/MNI_0591/S580960184.jpg to ../data/usq/oneoff/MNI_0591/images/S580960184.jpg
# ...
# copying ../data/usq/train_mra_mip/MNI_0663/S572080103.jpg to ../data/usq/oneoff/MNI_0663/images/S572080103.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080104.jpg to ../data/usq/oneoff/MNI_0663/images/S572080104.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080105.jpg to ../data/usq/oneoff/MNI_0663/images/S572080105.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080106.jpg to ../data/usq/oneoff/MNI_0663/images/S572080106.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080107.jpg to ../data/usq/oneoff/MNI_0663/images/S572080107.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080108.jpg to ../data/usq/oneoff/MNI_0663/images/S572080108.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080109.jpg to ../data/usq/oneoff/MNI_0663/images/S572080109.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080110.jpg to ../data/usq/oneoff/MNI_0663/images/S572080110.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080111.jpg to ../data/usq/oneoff/MNI_0663/images/S572080111.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080112.jpg to ../data/usq/oneoff/MNI_0663/images/S572080112.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080113.jpg to ../data/usq/oneoff/MNI_0663/images/S572080113.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080114.jpg to ../data/usq/oneoff/MNI_0663/images/S572080114.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080115.jpg to ../data/usq/oneoff/MNI_0663/images/S572080115.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080116.jpg to ../data/usq/oneoff/MNI_0663/images/S572080116.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080117.jpg to ../data/usq/oneoff/MNI_0663/images/S572080117.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080118.jpg to ../data/usq/oneoff/MNI_0663/images/S572080118.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080119.jpg to ../data/usq/oneoff/MNI_0663/images/S572080119.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080120.jpg to ../data/usq/oneoff/MNI_0663/images/S572080120.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080121.jpg to ../data/usq/oneoff/MNI_0663/images/S572080121.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080122.jpg to ../data/usq/oneoff/MNI_0663/images/S572080122.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080123.jpg to ../data/usq/oneoff/MNI_0663/images/S572080123.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080124.jpg to ../data/usq/oneoff/MNI_0663/images/S572080124.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080125.jpg to ../data/usq/oneoff/MNI_0663/images/S572080125.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080126.jpg to ../data/usq/oneoff/MNI_0663/images/S572080126.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080127.jpg to ../data/usq/oneoff/MNI_0663/images/S572080127.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080128.jpg to ../data/usq/oneoff/MNI_0663/images/S572080128.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080129.jpg to ../data/usq/oneoff/MNI_0663/images/S572080129.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080130.jpg to ../data/usq/oneoff/MNI_0663/images/S572080130.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080131.jpg to ../data/usq/oneoff/MNI_0663/images/S572080131.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080132.jpg to ../data/usq/oneoff/MNI_0663/images/S572080132.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080133.jpg to ../data/usq/oneoff/MNI_0663/images/S572080133.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080134.jpg to ../data/usq/oneoff/MNI_0663/images/S572080134.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080135.jpg to ../data/usq/oneoff/MNI_0663/images/S572080135.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080136.jpg to ../data/usq/oneoff/MNI_0663/images/S572080136.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080137.jpg to ../data/usq/oneoff/MNI_0663/images/S572080137.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080138.jpg to ../data/usq/oneoff/MNI_0663/images/S572080138.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080139.jpg to ../data/usq/oneoff/MNI_0663/images/S572080139.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080140.jpg to ../data/usq/oneoff/MNI_0663/images/S572080140.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080141.jpg to ../data/usq/oneoff/MNI_0663/images/S572080141.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080142.jpg to ../data/usq/oneoff/MNI_0663/images/S572080142.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080143.jpg to ../data/usq/oneoff/MNI_0663/images/S572080143.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080144.jpg to ../data/usq/oneoff/MNI_0663/images/S572080144.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080145.jpg to ../data/usq/oneoff/MNI_0663/images/S572080145.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080146.jpg to ../data/usq/oneoff/MNI_0663/images/S572080146.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080147.jpg to ../data/usq/oneoff/MNI_0663/images/S572080147.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080148.jpg to ../data/usq/oneoff/MNI_0663/images/S572080148.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080149.jpg to ../data/usq/oneoff/MNI_0663/images/S572080149.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080150.jpg to ../data/usq/oneoff/MNI_0663/images/S572080150.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080151.jpg to ../data/usq/oneoff/MNI_0663/images/S572080151.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080152.jpg to ../data/usq/oneoff/MNI_0663/images/S572080152.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080153.jpg to ../data/usq/oneoff/MNI_0663/images/S572080153.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080154.jpg to ../data/usq/oneoff/MNI_0663/images/S572080154.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080155.jpg to ../data/usq/oneoff/MNI_0663/images/S572080155.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080156.jpg to ../data/usq/oneoff/MNI_0663/images/S572080156.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080157.jpg to ../data/usq/oneoff/MNI_0663/images/S572080157.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080158.jpg to ../data/usq/oneoff/MNI_0663/images/S572080158.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080159.jpg to ../data/usq/oneoff/MNI_0663/images/S572080159.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080160.jpg to ../data/usq/oneoff/MNI_0663/images/S572080160.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080161.jpg to ../data/usq/oneoff/MNI_0663/images/S572080161.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080162.jpg to ../data/usq/oneoff/MNI_0663/images/S572080162.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080163.jpg to ../data/usq/oneoff/MNI_0663/images/S572080163.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080164.jpg to ../data/usq/oneoff/MNI_0663/images/S572080164.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080165.jpg to ../data/usq/oneoff/MNI_0663/images/S572080165.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080166.jpg to ../data/usq/oneoff/MNI_0663/images/S572080166.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080167.jpg to ../data/usq/oneoff/MNI_0663/images/S572080167.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080168.jpg to ../data/usq/oneoff/MNI_0663/images/S572080168.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080169.jpg to ../data/usq/oneoff/MNI_0663/images/S572080169.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080170.jpg to ../data/usq/oneoff/MNI_0663/images/S572080170.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080171.jpg to ../data/usq/oneoff/MNI_0663/images/S572080171.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080172.jpg to ../data/usq/oneoff/MNI_0663/images/S572080172.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080173.jpg to ../data/usq/oneoff/MNI_0663/images/S572080173.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080174.jpg to ../data/usq/oneoff/MNI_0663/images/S572080174.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080175.jpg to ../data/usq/oneoff/MNI_0663/images/S572080175.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080176.jpg to ../data/usq/oneoff/MNI_0663/images/S572080176.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080177.jpg to ../data/usq/oneoff/MNI_0663/images/S572080177.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080178.jpg to ../data/usq/oneoff/MNI_0663/images/S572080178.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080179.jpg to ../data/usq/oneoff/MNI_0663/images/S572080179.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080180.jpg to ../data/usq/oneoff/MNI_0663/images/S572080180.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080181.jpg to ../data/usq/oneoff/MNI_0663/images/S572080181.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080182.jpg to ../data/usq/oneoff/MNI_0663/images/S572080182.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080183.jpg to ../data/usq/oneoff/MNI_0663/images/S572080183.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080184.jpg to ../data/usq/oneoff/MNI_0663/images/S572080184.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080185.jpg to ../data/usq/oneoff/MNI_0663/images/S572080185.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080186.jpg to ../data/usq/oneoff/MNI_0663/images/S572080186.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080187.jpg to ../data/usq/oneoff/MNI_0663/images/S572080187.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080188.jpg to ../data/usq/oneoff/MNI_0663/images/S572080188.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080189.jpg to ../data/usq/oneoff/MNI_0663/images/S572080189.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080190.jpg to ../data/usq/oneoff/MNI_0663/images/S572080190.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080191.jpg to ../data/usq/oneoff/MNI_0663/images/S572080191.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080192.jpg to ../data/usq/oneoff/MNI_0663/images/S572080192.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080193.jpg to ../data/usq/oneoff/MNI_0663/images/S572080193.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080194.jpg to ../data/usq/oneoff/MNI_0663/images/S572080194.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080195.jpg to ../data/usq/oneoff/MNI_0663/images/S572080195.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080196.jpg to ../data/usq/oneoff/MNI_0663/images/S572080196.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080197.jpg to ../data/usq/oneoff/MNI_0663/images/S572080197.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080198.jpg to ../data/usq/oneoff/MNI_0663/images/S572080198.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080199.jpg to ../data/usq/oneoff/MNI_0663/images/S572080199.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080200.jpg to ../data/usq/oneoff/MNI_0663/images/S572080200.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080201.jpg to ../data/usq/oneoff/MNI_0663/images/S572080201.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080202.jpg to ../data/usq/oneoff/MNI_0663/images/S572080202.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080203.jpg to ../data/usq/oneoff/MNI_0663/images/S572080203.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080204.jpg to ../data/usq/oneoff/MNI_0663/images/S572080204.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080205.jpg to ../data/usq/oneoff/MNI_0663/images/S572080205.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080206.jpg to ../data/usq/oneoff/MNI_0663/images/S572080206.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080207.jpg to ../data/usq/oneoff/MNI_0663/images/S572080207.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080208.jpg to ../data/usq/oneoff/MNI_0663/images/S572080208.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080209.jpg to ../data/usq/oneoff/MNI_0663/images/S572080209.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080210.jpg to ../data/usq/oneoff/MNI_0663/images/S572080210.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080211.jpg to ../data/usq/oneoff/MNI_0663/images/S572080211.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080212.jpg to ../data/usq/oneoff/MNI_0663/images/S572080212.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080213.jpg to ../data/usq/oneoff/MNI_0663/images/S572080213.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080214.jpg to ../data/usq/oneoff/MNI_0663/images/S572080214.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080215.jpg to ../data/usq/oneoff/MNI_0663/images/S572080215.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080216.jpg to ../data/usq/oneoff/MNI_0663/images/S572080216.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080217.jpg to ../data/usq/oneoff/MNI_0663/images/S572080217.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080218.jpg to ../data/usq/oneoff/MNI_0663/images/S572080218.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080219.jpg to ../data/usq/oneoff/MNI_0663/images/S572080219.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080220.jpg to ../data/usq/oneoff/MNI_0663/images/S572080220.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080221.jpg to ../data/usq/oneoff/MNI_0663/images/S572080221.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080222.jpg to ../data/usq/oneoff/MNI_0663/images/S572080222.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080223.jpg to ../data/usq/oneoff/MNI_0663/images/S572080223.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080224.jpg to ../data/usq/oneoff/MNI_0663/images/S572080224.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080225.jpg to ../data/usq/oneoff/MNI_0663/images/S572080225.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080226.jpg to ../data/usq/oneoff/MNI_0663/images/S572080226.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080227.jpg to ../data/usq/oneoff/MNI_0663/images/S572080227.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080228.jpg to ../data/usq/oneoff/MNI_0663/images/S572080228.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080229.jpg to ../data/usq/oneoff/MNI_0663/images/S572080229.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080230.jpg to ../data/usq/oneoff/MNI_0663/images/S572080230.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080231.jpg to ../data/usq/oneoff/MNI_0663/images/S572080231.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080232.jpg to ../data/usq/oneoff/MNI_0663/images/S572080232.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080233.jpg to ../data/usq/oneoff/MNI_0663/images/S572080233.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080234.jpg to ../data/usq/oneoff/MNI_0663/images/S572080234.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080235.jpg to ../data/usq/oneoff/MNI_0663/images/S572080235.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080236.jpg to ../data/usq/oneoff/MNI_0663/images/S572080236.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080237.jpg to ../data/usq/oneoff/MNI_0663/images/S572080237.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080238.jpg to ../data/usq/oneoff/MNI_0663/images/S572080238.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080239.jpg to ../data/usq/oneoff/MNI_0663/images/S572080239.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080240.jpg to ../data/usq/oneoff/MNI_0663/images/S572080240.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080241.jpg to ../data/usq/oneoff/MNI_0663/images/S572080241.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080242.jpg to ../data/usq/oneoff/MNI_0663/images/S572080242.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080243.jpg to ../data/usq/oneoff/MNI_0663/images/S572080243.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080244.jpg to ../data/usq/oneoff/MNI_0663/images/S572080244.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080245.jpg to ../data/usq/oneoff/MNI_0663/images/S572080245.jpg
# copying ../data/usq/train_mra_mip/MNI_0663/S572080246.jpg to ../data/usq/oneoff/MNI_0663/images/S572080246.jpg

# %%
I_RY
# Out:
# array([[ 0.8660254,  0.       ,  0.5      ],
#        [ 0.       ,  1.       ,  0.       ],
#        [-0.5      ,  0.       ,  0.8660254]])

# %%
def create_gif(filenames, duration):
    images = []
    for filename in filenames:
        images.append(imageio.imread(filename))
    output_file = 'Gif-%s.gif' % datetime.datetime.now().strftime('%Y-%M-%d-%H-%M-%S')
    imageio.mimsave(output_file, images, duration=duration)

# %%
def create_mipGIF_from_3D(img,nb_image=40,duration=0.1,is_mask=False,borne_max=None):
    ls_mip=[]

    img_data=img
    #img_data+=1e-5
    
    for angle in np.linspace(0,360,nb_image):
        ls_slice=[]
        vol_angle= scipy.ndimage.interpolation.rotate(img_data,angle)
        
        MIP=np.amax(vol_angle,axis=1)
        #MIP-=1e-5
        MIP[MIP<1e-5]=0
        MIP=np.flipud(MIP.T)
        ls_mip.append(MIP)
    try:
        shutil.rmtree('test_gif/')
    except:
        pass
    os.mkdir('test_gif/')

    ls_image=[]
    for mip,i in zip(ls_mip,range(len(ls_mip))):
        fig,ax=plt.subplots()
        ax.set_axis_off()
        if borne_max is None:
            if is_mask==True:
                borne_max=1
            else:
                borne_max=15000
        plt.imshow(mip,cmap='Greys',vmax=borne_max)
        fig.savefig('test_gif/MIP'+'%04d' % (i)+'.png')
        plt.close(fig)

    filenames=glob.glob('test_gif/*.png')
    #print(filenames)
    create_gif(filenames, duration)
    try:
        shutil.rmtree('test_gif/')
    except:
        pass

# %%
create_mipGIF_from_3D(img_3d, nb_image=247)

# %%
# make image projections
import numpy as np
import SimpleITK as sitk

def make_mips(image_path, output_dir):
    image = sitk.GetImageFromArray(image_path)
    image_size = image.GetSize()

    basename = os.path.basename(output_dir)
    if not os.path.isdir(output_dir):
        os.makedirs(output_dir)

    for dim in range(3):
        projection = sitk.MaximumProjection(image, dim)

        if image_size[dim] % 2:  # odd number
            voxel = [0, 0, 0]
            voxel[dim] = (image_size[dim] - 1) / 2
            origin = image.TransformIndexToPhysicalPoint(voxel)
        else:  # even
            voxel1 = np.array([0, 0, 0], int)
            voxel2 = np.array([0, 0, 0], int)
            voxel1[dim] = image_size[dim] / 2 - 1
            voxel2[dim] = image_size[dim] / 2
            point1 = np.array(image.TransformIndexToPhysicalPoint(voxel1.tolist()))
            point2 = np.array(image.TransformIndexToPhysicalPoint(voxel2.tolist()))
            origin = np.mean(np.vstack((point1, point2)), 0)
        projection.SetOrigin(origin)
        projection.SetDirection(image.GetDirection())
        proj_basename = os.path.join(basename, f'{dim}.jpg')
        sitk.WriteImage(projection, os.path.join(output_dir, proj_basename))

# %%
def load_images (img_dir, file_list, d, h, w): 
    limg = np.ndarray(shape=(d, h, w), dtype=np.uint16)
    i=0
    for f in file_list:
        img = cv2.imread(os.path.join(img_dir, f))
        limg[i]=img[:,:,0] 
        i=i+1
    return limg

# %%
def convert_3d_mip(parent_dir, omit, source_dir = 'original_mra', target_dir = 'mra_mip'):
    #do images
    for subdir in os.listdir(os.path.join(parent_dir, source_dir)):
        # leave out MRI for test
        if subdir in omit:
            continue
        full_img_subdir = os.path.join(parent_dir, source_dir, subdir)
        #print(f'full {full_img_subdir}')
        fnames = os.listdir(full_img_subdir)
        img_3d = load_images(full_img_subdir, fnames, len(fnames), 320, 320)
        tgt_dir =  os.path.join(parent_dir, target_dir, subdir)
        print(tgt_dir)
        os.makedirs(tgt_dir, exist_ok=True)
        img_mip = make_mips(img_3d, tgt_dir)
        # create target dir

# %%
train_list = ['MNI_0590', 'MNI_0591', 'MNI_0592', 'MNI_0640', 'MNI_0643', 'MNI_0648', 'MNI_0656', 'MNI_0657', 'MNI_0663']
test_list = ['MNI_0664']

# %%
fnames = os.listdir('../data/usq/tst_orig_ip/MNI_0590')
img_3d = load_images('../data/usq/tst_orig_ip/MNI_0590', fnames, len(fnames), 320, 320)

# %%
img_3d.shape
# Out:
# (247, 320, 320)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#X, Y, Z = axes3d.get_test_data(0.1)
ax.plot_wireframe(img_3d[:,0,0], img_3d[0,:,0], img_3d[:,0,0], rstride=5, cstride=5)

# rotate the axes and update
for angle in range(0, 360):
   ax.view_init(30, angle)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a80be420e19e> in <module>
#       6
#       7 #X, Y, Z = axes3d.get_test_data(0.1)
# ----> 8 ax.plot_wireframe(img_3d[:,0,0], img_3d[0,:,0], img_3d[:,0,0], rstride=5, cstride=5)
#       9
#      10 # rotate the axes and update
#
# /anaconda/envs/fastai/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_wireframe(self, X, Y, Z, *args, **kwargs)
#    1792         had_data = self.has_data()
#    1793         if Z.ndim != 2:
# -> 1794             raise ValueError("Argument Z must be 2-dimensional.")
#    1795         # FIXME: Support masked arrays
#    1796         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
img_3d.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-afca44647e8d> in <module>
# ----> 1 img_3d.shape
#
# NameError: name 'img_3d' is not defined

# %%
plt.imshow(img_3d[246, :, :])

# %%
m1 = np.rot90(img_3d, axes=(0,1))
m2 = np.rot90(img_3d, axes=(1,2))
m3 = np.rot90(img_3d, axes=(0,2))

# %%
plt.imshow(img_3d[246, :, :])

# %%
plt.imshow(m1[246, :, :])

# %%
plt.imshow(m2[246, :, :])

# %%
plt.imshow(m3[246, :, :])
